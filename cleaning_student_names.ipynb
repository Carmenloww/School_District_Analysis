# %%
# Add the dependencies.
import pandas as pd
import os

# %%
# Files to load
school_data_to_load = os.path.join("Resources", "schools_complete.csv")
student_data_to_load = os.path.join("Resources", "students_complete.csv")

# %%
# Read the student data file and store it in a Pandas DataFrame.
student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Dr. Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Dr. Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
#  'Natalie Mitchell',
#  'Tiffany Gutierrez',
#  'Jennifer Hess',
#  'Christine Fletcher',
#  'Jon Smith',
#  'Tracey Yates',
#  'Jerry Gordon',
#  'Michael Cox',
#  'Madeline Snyder MD',
#  'Allison King',
#  'Theresa Meyer',
#  'Jared Wood',
#  'Eric Maynard',
#  'Mark Owens',
#  'Ronnie Conley',
#  'Kimberly Davis',
#  'Amy Mitchell',
#  'Mr. Dylan Taylor MD',
#  'Elizabeth Henderson',
#  'James Lopez',
#  'Michael Morgan',
#  'Angela Francis',
#  'Breanna Taylor',
#  'Jason Johnson',
#  'Kyle Martin',
#  'Dr. Scott Gill',
#  'Lisa Long',
#  'Erin Liu',
#  'Marcus Richards',
#  'Jason Thompson',
#  'Elizabeth Mckinney',
#  'Jessica Bailey',
#  'Lisa Frye',
#  'Lindsey Baker',
#  'Lisa Ramirez',
#  'Joseph Butler',
#  'Tina Lynch',
#  'Leah Benitez',
#  'Elizabeth Parker',
#  'Melissa Hunter',
#  'Miss Madison Everett',
#  'Ronald Garcia',
#  'Mark Cherry',
#  'Ryan Stokes',
#  'Isaiah Maldonado',
#  'Micheal Dennis',
#  'Kevin Martinez',
#  'Jessica Smith',
#  'Dawn Trujillo',
#  'Virginia Ramirez MD',
#  'Marc Hernandez',
#  'Jose Gonzalez',
#  'Jason Dennis',
#  'Gary Morris',
#  'William Mcdonald',
#  'Michael Savage',
#  'Alexis Todd',
#  'David Hansen',
#  'Steven Mendez',
#  'Ryan Lynch',
#  'Timothy Marks',
#  'Alexander Johns',
#  'Kenneth Chavez',
#  'Dennis Williams',
#  'Michael Roy',
#  'Richard Ryan',
#  'Matthew Reyes',
#  'Stephanie Ward',
#  'Christopher Tucker',
#  'Daniel Jones',
#  'Devin Craig',
#  'Erin Prince',
#  'Bernard Ortiz',
#  'Nicole Miller',
#  'Christopher Fritz',
#  'Bonnie Mckinney',
#  'Troy Nelson',
#  'Jennifer Lee',
#  'Ronald Ward',
#  'Nathaniel Hampton',
#  'Michael Travis',
#  'James Taylor',
#  'Thomas Strickland',
#  'Brittany Jackson',
#  'Marisa Lowe',
#  'Nicole Thomas',
#  'Matthew Rodriguez',
#  'Kent Fernandez',
#  'Michelle Martin',
#  'John Sparks',
#  'Ann Blake',
#  'Melissa Miller',
#  'Steven Houston',
#  'Kristen Anderson',
#  'Cory Jones',
#  'Jennifer Mora',
#  'Dennis Griffin',
#  'Darryl Brown',
#  'Martin Mosley',
#  'Joyce Diaz',
#  'Jeffrey Rose',
#  'Jamie Moreno',
#  'Catherine Williams',
#  'Lauren Byrd',
#  'Vanessa Frazier',
#  'Stephen Bryant',
#  'Lawrence Liu',
#  'Joseph Larsen',
#  'Susan Collier',
#  'Meagan Jensen',
#  'Julie Harper',
#  'Meghan Carroll',
#  'Wanda Horton',
#  'Mary Campbell',
#  'Jennifer Rodgers',
#  'Heather Cooper',
#  'Ryan Perez',
#  'Ryan Cox',
#  'Darren Zavala',
#  'Joseph Morales III',
#  'Aaron West',
#  'James Combs',
#  'Curtis Garner',
#  'Sarah Miller',
#  'Samantha Thomas',
#  'Robert Atkins',
#  'Alexis Crawford',
#  'Ryan Maddox',
#  'Jonathan Meyer',
#  'Donna Wagner',
#  'William Kennedy',
#  'Kimberly Martinez',
#  'Matthew Anderson',
#  'Kari Miller',
#  'Jenna Luna',
#  'Justin Contreras',
#  'Mary Fox',
#  'Joseph Perkins',
#  'Kelly Phillips',
#  'Justin Thornton',
#  'Joshua Barber',
#  'Travis Jackson',
#  'Jordan Beasley',
#  'Kevin Allen',
#  'Victoria Harris',
#  'Victoria Joseph',
#  'Brandy Marshall',
#  'Ryan Jimenez',
#  'Michael Chan',
#  'Christopher Phillips',
#  'Kevin Murphy',
#  'Vanessa Harper',
#  'James Ferguson',
#  'Carol Schroeder',
#  'Jerry Phillips',
#  'Kristin Wade',
#  'Jessica Warner',
#  'Dorothy Burke',
#  'Bethany Walter',
#  'Melissa Avery',
#  'Daniel Sutton',
#  'Ryan Johnson',
#  'Timothy Quinn',
#  'Zachary Allen',
#  'Lauren Schmitt',
#  'Stephanie Armstrong',
#  'Ruben Rivera',
#  'Patricia Petty',
#  'Joseph Jacobs',
#  'Bianca Wilson',
#  'Donald Perez',
#  'Curtis Gomez',
#  'Courtney Brown',
#  'Nicole Randall',
#  'Steven Lambert',
#  'Anthony Alvarez',
#  'Shawn Farrell',
#  'Jesus Schmidt',
#  'Laura Wright',
#  'Steven Smith',
#  'Norman Thompson',
#  'Anthony Wright',
#  'Kayla Watts',
#  'Aimee Johnson',
#  'Heidi Scott',
#  'Anthony Williams',
#  'Sarah Hill',
#  'Kim Wang',
#  'Beth Manning',
#  'Ryan Hanson',
#  'James Wood',
#  'Corey Greene',
#  'John Carter',
#  'Beth Garza',
#  'Karen Jones',
#  'Stephanie Poole',
#  'Lisa Brown',
#  'Paul Scott',
#  'Evelyn Buck',
#  'Terry Harrell',
#  'Leah Skinner',
#  'Anthony Mercado',
#  'Walter Kelly',
#  'Lori Evans',
#  'Ashley Jones',
#  'Amber Soto',
#  'Patrick Phillips',
#  'Linda Curry',
#  'Alexander Obrien',
#  'Vincent Garza',
#  'Terry Marsh',
#  'Angela Perkins DVM',
#  'Peter Hampton',
#  'David Cross',
#  'Clinton Ortega',
#  'Jamie Escobar',
#  'Sandra Mason',
#  'Craig Cole',
#  'Lisa Warren',
#  'Maria Howard',
#  'Michael Porter',
#  'John Turner',
#  'Timothy Wang',
#  'Amanda Taylor',
#  'Karen Mckenzie',
#  'Brandon Miles',
#  'Christina Whitaker',
#  'Nicole Peterson',
#  'Ashley Moore',
#  'Todd Carrillo',
#  'Robert Williams',
#  'Ashley Jones',
#  'Vanessa Parker',
#  'Robert Carlson',
#  'Jared Lewis',
#  'Christopher Hernandez',
#  'Kimberly Harris',
#  'Katrina Hill',
#  'Heather Lee',
#  'Donald Harmon',
#  'Elizabeth Sanders',
#  'Richard Ramsey',
#  'Carmen Johnson',
#  'Elaine Osborne',
#  'Kent Burns',
#  'Meagan Smith',
#  'Craig Hahn',
#  'Jeremy Wu',
#  'Aaron Rodriguez',
#  'Matthew Taylor',
#  'Diana Evans',
#  'Michele Pearson',
#  'Erik Wagner',
#  'Maria Welch',
#  'Debra Martin',
#  'Devon Conner',
#  'Christine Patel',
#  'David Lopez',
#  'Nathan Baird',
#  'Samuel Castillo',
#  'Rebecca Payne',
#  'Carl Johnson',
#  'William Adams',
#  'Paula Harrison',
#  'Wayne Atkinson',
#  'Lindsay Frank',
#  'Jose Garcia',
#  'Andrew Gaines',
#  'Rachael Liu',
#  'Donald Lewis',
#  'Shane Edwards',
#  'Todd Levy',
#  'Joanna Moore',
#  'Michael Lewis',
#  'James Robinson',
#  'Jeffrey Arellano',
#  'Heather Allen MD',
#  'Lori Villarreal',
#  'Robert Harper',
#  'Karen Villegas',
#  'Tracey Crane',
#  'Elizabeth Allen',
#  'Jorge Lynn',
#  'Harold Gordon',
#  'Nicholas Mcclain',
#  'Tanya Harris',
#  'Amy Smith',
#  'Kathy Morse',
#  'Andrea Wood',
#  'Maureen Massey',
#  'Daniel Smith',
#  'Alexandra Smith',
#  'Caitlin Hall',
#  'Jose Carlson',
#  'Deborah Macias',
#  'Dwayne Rice',
#  'Matthew Harris',
#  'Eric Bowman',
#  'Samuel Ali',
#  'David Miller',
#  'James Moreno',
#  'Brooke Austin',
#  'Alisha Martin',
#  'Neil Rodriguez',
#  'Gary Williams',
#  'Michael Pittman',
#  'Stephanie Palmer',
#  'Christine Perry',
#  'Suzanne David',
#  'Amber Smith',
#  'Ryan Jones',
#  'Emily Ford',
#  'Kelsey Shea',
#  'Katherine Wallace',
#  'Erica Conway',
#  'Tyler Parker',
#  'Michael Parks',
#  'Elizabeth Hunt',
#  'Grant Jackson',
#  'Daniel Matthews',
#  'Diana Silva',
#  'Frank Garza',
#  'Terri Fischer',
#  'Robert Goodwin',
#  'Bobby Ruiz',
#  'Stephanie Taylor',
#  'Erin Hill',
#  'Erin Cohen',
#  'Jeffrey Morris',
#  'Elizabeth Simpson',
#  'Jennifer Davis',
#  'Rachel Burton',
#  'Joseph Wilkins',
#  'Lawrence Montgomery',
#  'Patricia Howard',
#  'Jessica Hanson',
#  'Donna Dean',
#  'Edwin Reid',
#  'Jodi Brown',
#  'Elizabeth Richard',
#  'Aaron Martinez',
#  'Stephen Fischer',
#  'Diana Reeves',
#  'Jeffrey Eaton',
#  'Evelyn Miller',
#  'Christopher Kidd',
#  'Sarah Adams',
#  'Melinda Nelson',
#  'Kevin Brooks',
#  'John Bowen',
#  'Tracie Abbott',
#  'Allen Foster',
#  'Kathryn Elliott',
#  'Christopher Walker',
#  'Cynthia Martin',
#  'Amanda Bennett',
#  'Dennis Padilla',
#  'Antonio Miller',
#  'Melissa Trevino',
#  'Andrew King',
#  'John Martinez',
#  'Lauren King',
#  'Stephanie Mercado',
#  'William Smith',
#  'Jonathan Marshall',
#  'Luke Lowery MD',
#  'Emily Reynolds',
#  'Kevin Mclean',
#  'Elizabeth Taylor',
#  'Pamela Rivas',
#  'Tammy Martin',
#  'Holly Watkins',
#  'Patrick Chen',
#  'Michelle Griffin',
#  'Theresa Andrews',
#  'Alan Henry',
#  'Dr. Larry Hines',
#  'Travis Frazier',
#  'Julie Jones',
#  'Natalie Reynolds',
#  'Jessica Cohen',
#  'Jason Robinson',
#  'Heather Palmer',
#  'Emily Cardenas MD',
#  'Scott Glover',
#  'Jacqueline White',
#  'Mrs. Elizabeth Espinoza DDS',
#  'Toni Porter',
#  'Jennifer Mejia',
#  'Brenda Peterson',
#  'Paul Hamilton',
#  'Patricia Nguyen',
#  'James Ho',
#  'Elizabeth Cohen',
#  'Stephanie Lane',
#  'Dawn Rhodes',
#  'Theresa Robinson',
#  'Breanna Mosley',
#  'Carmen Wilson',
#  'Ian Brown',
#  'Kathleen Matthews',
#  'Bryan Diaz',
#  'Gina Sweeney',
#  'Alan Garcia',
#  'Erik Wheeler',
#  'Stephanie Robles',
#  'Samantha Hanson',
#  'Christopher Williams',
#  'Stephanie Hart',
#  'Mrs. Lisa Becker',
#  'Bianca Johnson',
#  'Amy Steele',
#  'Gina Contreras',
#  'Jaime Alexander',
#  'Kevin Coleman',
#  'Caitlin Williams',
#  'Joseph Lloyd',
#  'Carrie Hernandez',
#  'Mr. Travis Young',
#  'Francis Wright',
#  'Joel Harper',
#  'Eduardo Park',
#  'Melissa Yoder',
#  'Donna Campbell',
#  'Connie Delacruz',
#  'Luis Parker',
#  'Pamela Watts',
#  'Lindsey Mitchell',
#  'Brenda Price',
#  'Joseph Howard',
#  'Amy Evans',
#  'Paula Fernandez DVM',
#  'Amber Cunningham',
#  'Preston Wheeler',
#  'James Lopez',
#  'Chad Drake',
#  'Samuel Blackburn',
#  'Shawn Nielsen',
#  'Eric Perez',
#  'Kevin Montgomery',
#  'Terry Thomas',
#  'Kim Meyer',
#  'Michael Townsend',
#  'Ronnie Rodriguez',
#  'Savannah Smith',
#  'Shane Nguyen',
#  'Michael Brown',
#  'Robert Young',
#  'Daniel Griffin',
#  'James Johnson',
#  'Mary Cox',
#  'Tina Aguirre',
#  'Jillian Mcdonald',
#  'Matthew Branch',
#  'Christopher Jordan',
#  'Victor Mcguire',
#  'Erin Arnold',
#  'Nicholas Wu',
#  'Kristen Wilson',
#  'Morgan Moore',
#  'Stephen Smith',
#  'Jeremy Romero',
#  'Julie Bush',
#  'Brittany Taylor',
#  'James Kim',
#  'Ashley Roberts',
#  'Brandon Johnson',
#  'David Davenport',
#  'Mark Washington',
#  'Alicia Marshall',
#  'Barbara Santana',
#  'Samantha Parker',
#  'Joseph Walters',
#  'Michael Zamora',
#  'Kyle Cobb',
#  'Jill Clark',
#  'Sarah Warren',
#  'Jennifer Robinson',
#  'Patricia Johnson',
#  'Henry Evans',
#  'Alexander Ramsey',
#  'Brandon Stephens',
#  'Jeff Holland',
#  'Samuel Schultz',
#  'Brett Johnson',
#  'Daniel Sherman',
#  'Justin Mccall',
#  'Jonathan Evans',
#  'Jacqueline Kennedy',
#  'Martin Stephenson',
#  'Lindsey Lane',
#  'Jessica Hart',
#  'Edward Lucas',
#  'Lisa Osborne',
#  'Hannah Black',
#  'Alexander Paul',
#  'Brenda Wong',
#  'Thomas Delgado',
#  'Jeremy Sutton',
#  'Paula Donaldson',
#  'Valerie Thompson',
#  'John Schaefer',
#  'Jesus Manning',
#  'Tyrone Lawson',
#  'Carl May',
#  'Brittany Russell',
#  'Philip Edwards',
#  'Robert Aguilar',
#  'Aaron Russo',
#  'Tracy Andrade',
#  'Amy Sullivan',
#  'Howard Beck',
#  'Dr. Xavier Bell II',
#  'Dawn Schultz',
#  'Caleb Lucas',
#  'Barbara Gonzalez',
#  'Charles Yang',
#  'David Gallagher',
#  'Bethany Vargas',
#  'Jennifer Schultz',
#  'Paula Marshall',
#  'Jordan Elliott',
#  'Samantha Mcmillan',
#  'Judith Johnson',
#  'Grace Palmer',
#  'Brandon Ramirez',
#  'Carol Smith',
#  'Matthew Odom',
#  'Erika Gray',
#  'Donna Kramer',
#  'Jonathan Snyder',
#  'Frank Howe',
#  'Amy Beck',
#  'Lori Holmes',
#  'Rebekah Hampton',
#  'Perry Bishop',
#  'Andrew Hanson MD',
#  'Jody Hughes',
#  'Anna Garcia',
#  'Colleen Walker',
#  'Danny Bridges',
#  'Kristina Ford',
#  'Sabrina Davidson',
#  'Alexander Freeman',
#  'Jack Davis',
#  'Victor Rivera',
#  'Elizabeth Pena',
#  'Neil Castro',
#  'Michael Briggs',
#  'Anna Andersen',
#  'Elizabeth Oconnor',
#  'Zachary Brooks',
#  'Scott Jackson',
#  'Mary Fuentes',
#  'Denise Reyes',
#  'Janice Collier',
#  'Tina Barber',
#  'Keith Rojas',
#  'Michelle Decker',
#  'James Smith',
#  'Alexandra Thompson',
#  'Jacqueline Campbell',
#  'Austin Clark',
#  'Brooke Thomas',
#  'Molly Smith',
#  'Pamela Beck',
#  'Timothy Morris',
#  'Lauren White',
#  'Jessica Beltran',
#  'Alexandra Jones',
#  'Evelyn Rice',
#  'Stephen Ellis',
#  'Caroline Smith',
#  'Fred Case',
#  'Crystal Anderson',
#  'Jordan Gross',
#  'Marie Harris',
#  'Charles Hayes',
#  'Beverly Sheppard',
#  'Denise Solis',
#  'Alexander Myers',
#  'Sally Robertson',
#  'Steven Morris',
#  'Nina Flores',
#  'Miguel Patterson',
#  'John Simpson',
#  'Charles Cruz',
#  'Monica Davis',
#  'James Fields',
#  'Kevin Frederick',
#  'Jeremy Soto',
#  'Ronald Harris',
#  'Carol Stewart',
#  'Albert Durham',
#  'James Sanchez',
#  'John Adams',
#  'Cody Williams',
#  'Ernest Love',
#  'Tommy Smith',
#  'Jared Anderson',
#  'Jennifer Yang',
#  'Joe Mercado',
#  'Mr. Roberto Wright MD',
#  'Michael Smith',
#  'William Park',
#  'Benjamin Williams',
#  'Dean Perez',
#  'Mr. Dale Miller',
#  'Marissa Russell',
#  'Mary Gonzalez DDS',
#  'April Jackson',
#  'William Hayes',
#  'Meghan Holloway',
#  'Amy Coleman',
#  'James Green',
#  'Michael Tran',
#  'Joseph Cortez',
#  'Anita Moss',
#  'Benjamin Stokes',
#  'Michael Li',
#  'Alexander Rosales',
#  'Katie Dawson',
#  'Shelly Erickson',
#  'Kathryn Turner',
#  'Jacob Lee',
#  'Ryan Smith',
#  'Joshua Fernandez',
#  'Mia Roach',
#  'William Rodriguez',
#  'Wanda Cruz',
#  'Pamela Hall',
#  'David Smith',
#  'Jason Brown',
#  'Chelsea Alexander',
#  'Kimberly Tate',
#  'Daniel Williams',
#  'Terri Jacobson',
#  'Paul Harris',
#  'Jessica Thompson',
#  'Nancy Hawkins',
#  'Deborah Phillips',
#  'Mark Mendoza',
#  'Stephen Williamson',
#  'Jennifer Strong',
#  'Matthew Moore',
#  'Raymond Parker',
#  'Lee Evans',
#  'Curtis Rodriguez',
#  'Sara Morris',
#  'Dawn Palmer',
#  'Brianna Benson',
#  'Luis Watts',
#  'Mrs. Cindy Brown',
#  'Summer Sandoval',
#  'Ashley Smith',
#  'Randy Wallace',
#  'Angela Simmons',
#  'Sandra Haley',
#  'George Morgan',
#  'Melissa Ali',
#  'Matthew Oliver',
#  'Michael Kirk',
#  'Terry Khan',
#  'Kristie Elliott',
#  'Joel Campbell',
#  'Anthony Henderson',
#  'Brent Christensen',
#  'Heidi Hayes',
#  'Ryan Mcbride',
#  'Kyle Murillo',
#  'Angela Powell',
#  'Jeanette Simmons',
#  'Adam Vance',
#  'Kristen Murray',
#  'Jessica Burnett',
#  'Alex Walker',
#  'Robert Phillips',
#  'Elizabeth Martinez',
#  'Kristina Young',
#  'Sarah Morgan',
#  'Cheryl Harding',
#  'Keith Hunter',
#  'Todd Williams',
#  'James White MD',
#  'Kyle Johnson',
#  'Andrea Suarez',
#  'Michael Sanchez',
#  'Jaime Torres',
#  'Donald Gill DDS',
#  'Austin Lee',
#  'Adrian Bowman',
#  'Julie Perez',
#  'Debra Maxwell',
#  'Bradley Phillips',
#  'Sonya Simmons',
#  'Eric Miller',
#  'Charles Berger',
#  'Mary Monroe',
#  'Destiny Burns',
#  'Patrick Khan',
#  'Nathaniel Henson',
#  'Larry Miller',
#  'Timothy French',
#  'Xavier Mitchell',
#  'Jason Crosby',
#  'Joshua Johnson',
#  'Alyssa Clark',
#  'Jonathan Cooper',
#  'Mark Hunt',
#  'Norman Moore',
#  'Brian Atkins',
#  'Zachary Jones',
#  'Danielle Wong',
#  'Patricia Lane',
#  'Joshua Rose',
#  'Hannah Montes',
#  'Mrs. Catherine Williams MD',
#  'Michael Jenkins',
#  'James Scott',
#  'Evan Ballard',
#  'Andrea Miller',
#  'Jasmine Lynch',
#  'Jennifer Fox',
#  'Jared Castro',
#  'Eugene Cox',
#  'Wendy Wilson',
#  'Debbie Smith',
#  'Michael Fletcher',
#  'Jay Waters',
#  'Melissa Martinez',
#  'Cory Howard',
#  'Mitchell Hanson',
#  'Corey Boyer',
#  'Elizabeth Gonzalez',
#  'Robert Hutchinson',
#  'David Hernandez',
#  'Tammy Jordan',
#  'Denise Johnson',
#  'Brandi Copeland',
#  'Evan Marshall',
#  'Gregory Long',
#  'Kristen Underwood',
#  'Walter French',
#  'Edwin Thompson',
#  'Edward Rivera',
#  'Brandon Wilson',
#  'Alejandra Todd',
#  'Dana Hoffman',
#  'David Howard',
#  'Ashley Caldwell MD',
#  'Cindy Horn',
#  'Kevin Armstrong',
#  'Stacey Porter',
#  'Patrick Hunt',
#  'David White',
#  'Tammy Black',
#  'Joanna Williams',
#  'Becky Moran',
#  'Brenda Smith',
#  'Gabrielle Webb',
#  'Mr. Jared Campbell',
#  'Ryan Jenkins',
#  'Thomas Shepard',
#  'Jeremiah Boyd',
#  'Matthew White',
#  'Christina Anderson',
#  'Edward Olson',
#  'Emily Bryant',
#  'Amy Guzman',
#  'Kathleen Owens',
#  'John Davila',
#  'Nicole King',
#  'Jason Villarreal',
#  'Matthew Washington',
#  'Peter Simpson',
#  'Cristian Espinoza',
#  'Steven Fry',
#  'David Miller',
#  'Tamara Hernandez',
#  'Jordan Lewis',
#  'Carol Anderson',
#  'Michael Moreno PhD',
#  'Nicholas Logan',
#  'Paul Anderson',
#  'Jason Young',
#  'Wesley Martin',
#  'Karen Wall',
#  'Tara Parker MD',
#  'Michael Reyes',
#  'Amy Henderson',
#  'Jessica Reed',
#  'Joseph Miranda',
#  'Mackenzie Jones',
#  'Jon Espinoza',
#  'Kelly Medina',
#  'Jason Rubio',
#  'Jennifer Munoz',
#  'Christopher Warner',
#  'Vincent Thomas',
#  'Andrew Young',
#  'David Jenkins',
#  'Daniel Stephens',
#  'Elizabeth Lewis',
#  'Aaron Moore',
#  'Lisa Hogan',
#  'Shawn Williams DVM',
#  'Michele Dickerson',
#  'Dr. Alicia Martinez',
#  'Mr. Timothy Anderson',
#  'Sierra Jackson',
#  'Sharon Taylor',
#  'Jeffrey Smith',
#  'Mark Taylor',
#  'Christina Ross',
#  'Judy Hall',
#  'Jennifer Fox',
#  'Kenneth Moran',
#  'Gerald Ferguson',
#  'Albert Carter',
#  'Michael Reilly',
#  'Kathleen Schwartz',
#  'Stacey Harris',
#  'Mrs. Paula Lee',
#  'Adrian Black',
#  'Rita Moreno',
#  'Jason Perry',
#  'Scott Ortiz',
#  'Randy Mueller',
#  'Samantha Anderson',
#  'Phillip Brown',
#  'Christina Kerr',
#  'Derrick Hill',
#  'Nathan Bond',
#  'Marie Wilson',
#  'Caitlin Jones',
#  'Barbara Campbell',
#  'Katie Gonzales',
#  'Mr. Elijah Hall',
#  'James Sanders',
#  'Nicholas Martinez',
#  'Maria Mack',
#  'Mary Mason',
#  'Tiffany Campbell',
#  'Mr. Raymond Stone',
#  'Dominique Henderson',
#  'Martin Williams',
#  'Hannah Parker',
#  'Susan Webb',
#  'Rachel Johnson',
#  'Darren Davis',
#  'Tim Carr',
#  'Jesus Ryan',
#  'John Hays',
#  'Scott Stewart',
#  'Alexandra Roberts',
#  'Amanda Norman',
#  'James Moody',
#  'Brenda Jones',
#  'Kathy Smith',
#  'Raymond Clark',
#  'Ashley Martin',
#  'Tamara Flowers',
#  'Cesar Hanson',
#  'Ross Strickland',
#  'Randy Moore',
#  'Henry Andersen',
#  'Paul Martin',
#  'Sarah Stanley',
#  'Jordan Lewis',
#  'Ashley Richardson',
#  'Michael Brown',
#  'Jason Davis',
#  'Wendy Mcclain',
#  'Troy Williams',
#  'Carrie Alexander',
#  'Kyle Ware',
#  'Michael Robinson',
#  'Roger Wilson',
#  'Teresa Fuller',
#  'Craig Silva',
#  'Duane Thomas',
#  'Jon Crosby',
#  'Jon Steele',
#  'Daniel Shaw',
#  'Gwendolyn Williams',
#  'Angela Hess',
#  'Cameron Arnold',
#  'Janice Garcia',
#  'Anne Bullock',
#  'Katie Moody',
#  'Kayla Rivas',
#  'Danny Pearson',
#  'Billy Robles',
#  'Michelle Delgado',
#  'Cindy Harrison',
#  'John Dickerson MD',
#  'Tina Armstrong',
#  'Mr. Alex Franklin',
#  'Ryan King',
#  'Christine Guzman',
#  'Helen Malone',
#  'Benjamin Carpenter',
#  'Mrs. Jessica Dunn',
#  'Jessica Kaiser',
#  'Brandon Black',
#  'David Hernandez',
#  'Brenda Turner',
#  'Katherine Black',
#  'Larry Santos',
#  'Zachary Dominguez',
#  'Tanya Fernandez',
#  'Joseph Nichols',
#  'Rebecca Martinez',
#  'Traci Ramirez',
#  'Ryan Bauer',
#  'Joshua Williams',
#  'Devon Foley',
#  'Heidi Walter',
#  'Mario Nguyen',
#  'Jordan Hernandez',
#  'William Miller',
#  'Nicholas Chung',
#  'Christine Cooley',
#  'Carrie Nelson',
#  'Crystal Fowler',
#  'Lori Taylor',
#  'Mr. Michael Stevenson',
#  'Matthew Holmes',
#  'David Walls',
#  'Megan Martin',
#  'Karen Peterson',
#  'Kristen Wallace',
#  'Mark Peterson',
#  'Jason Jones DDS',
#  'Keith Barber',
#  'Patrick Green',
#  'Antonio Lopez',
#  'Travis Peterson',
#  'Gabriel Hunter',
#  'Amanda Ross',
#  'Samuel Thompson',
#  'Robert Bowman',
#  'Cynthia Cox',
#  'Brittany Miller',
#  'Eric Torres',
#  'Sandra Calhoun',
#  'Jacob Bailey',
#  'Jessica Harris',
#  'Molly Carr',
#  'Keith Davis',
#  'Adriana Wade MD',
#  ...]

# %%
# Split the student name and determine the length of the split name.
for name in student_names:
    print(name.split(), len(name.split()))
# Out:
# ['Paul', 'Bradley'] 2
# ['Victor', 'Smith'] 2
# ['Kevin', 'Rodriguez'] 2
# ['Dr.', 'Richard', 'Scott'] 3
# ['Bonnie', 'Ray'] 2
# ['Bryan', 'Miranda'] 2
# ['Sheena', 'Carter'] 2
# ['Nicole', 'Baker'] 2
# ['Michael', 'Roth'] 2
# ['Matthew', 'Greene'] 2
# ['Andrew', 'Alexander'] 2
# ['Daniel', 'Cooper'] 2
# ['Brittney', 'Walker'] 2
# ['William', 'Long'] 2
# ['Tammy', 'Hebert'] 2
# ['Dr.', 'Jordan', 'Carson'] 3
# ['Donald', 'Zamora'] 2
# ['Kimberly', 'Santiago'] 2
# ['Kevin', 'Stevens'] 2
# ['Brandi', 'Lyons'] 2
# ['Lisa', 'Davis'] 2
# ['Kristen', 'Lopez'] 2
# ['Kimberly', 'Stewart'] 2
# ['Christopher', 'Parker'] 2
# ['Chelsea', 'Griffith'] 2
# ['Cesar', 'Morris'] 2
# ['Melanie', 'Decker'] 2
# ['Tracey', 'Oconnor'] 2
# ['Kelly', 'James'] 2
# ['Nicole', 'Brown'] 2
# ['Bobby', 'Harris'] 2
# ['Brian', 'Fernandez'] 2
# ['Candace', 'Phelps'] 2
# ['Amy', 'Gonzalez'] 2
# ['Steven', 'Green'] 2
# ['Benjamin', 'Carlson'] 2
# ['Kevin', 'Bailey'] 2
# ['Jesse', 'Newton'] 2
# ['Kimberly', 'Mercado'] 2
# ['Gregory', 'Roberts'] 2
# ['Matthew', 'Mayer'] 2
# ['Jennifer', 'Parks'] 2
# ['John', 'Carlson'] 2
# ['Megan', 'Roberts'] 2
# ['Debra', 'Flores'] 2
# ['Heidi', 'Jackson'] 2
# ['Denise', 'Bradford'] 2
# ['Ellen', 'Brown'] 2
# ['Amy', 'Perkins'] 2
# ['Natalie', 'Mitchell'] 2
# ['Tiffany', 'Gutierrez'] 2
# ['Jennifer', 'Hess'] 2
# ['Christine', 'Fletcher'] 2
# ['Jon', 'Smith'] 2
# ['Tracey', 'Yates'] 2
# ['Jerry', 'Gordon'] 2
# ['Michael', 'Cox'] 2
# ['Madeline', 'Snyder', 'MD'] 3
# ['Allison', 'King'] 2
# ['Theresa', 'Meyer'] 2
# ['Jared', 'Wood'] 2
# ['Eric', 'Maynard'] 2
# ['Mark', 'Owens'] 2
# ['Ronnie', 'Conley'] 2
# ['Kimberly', 'Davis'] 2
# ['Amy', 'Mitchell'] 2
# ['Mr.', 'Dylan', 'Taylor', 'MD'] 4
# ['Elizabeth', 'Henderson'] 2
# ['James', 'Lopez'] 2
# ['Michael', 'Morgan'] 2
# ['Angela', 'Francis'] 2
# ['Breanna', 'Taylor'] 2
# ['Jason', 'Johnson'] 2
# ['Kyle', 'Martin'] 2
# ['Dr.', 'Scott', 'Gill'] 3
# ['Lisa', 'Long'] 2
# ['Erin', 'Liu'] 2
# ['Marcus', 'Richards'] 2
# ['Jason', 'Thompson'] 2
# ['Elizabeth', 'Mckinney'] 2
# ['Jessica', 'Bailey'] 2
# ['Lisa', 'Frye'] 2
# ['Lindsey', 'Baker'] 2
# ['Lisa', 'Ramirez'] 2
# ['Joseph', 'Butler'] 2
# ['Tina', 'Lynch'] 2
# ['Leah', 'Benitez'] 2
# ['Elizabeth', 'Parker'] 2
# ['Melissa', 'Hunter'] 2
# ['Miss', 'Madison', 'Everett'] 3
# ['Ronald', 'Garcia'] 2
# ['Mark', 'Cherry'] 2
# ['Ryan', 'Stokes'] 2
# ['Isaiah', 'Maldonado'] 2
# ['Micheal', 'Dennis'] 2
# ['Kevin', 'Martinez'] 2
# ['Jessica', 'Smith'] 2
# ['Dawn', 'Trujillo'] 2
# ['Virginia', 'Ramirez', 'MD'] 3
# ['Marc', 'Hernandez'] 2
# ['Jose', 'Gonzalez'] 2
# ['Jason', 'Dennis'] 2
# ['Gary', 'Morris'] 2
# ['William', 'Mcdonald'] 2
# ['Michael', 'Savage'] 2
# ['Alexis', 'Todd'] 2
# ['David', 'Hansen'] 2
# ['Steven', 'Mendez'] 2
# ['Ryan', 'Lynch'] 2
# ['Timothy', 'Marks'] 2
# ['Alexander', 'Johns'] 2
# ['Kenneth', 'Chavez'] 2
# ['Dennis', 'Williams'] 2
# ['Michael', 'Roy'] 2
# ['Richard', 'Ryan'] 2
# ['Matthew', 'Reyes'] 2
# ['Stephanie', 'Ward'] 2
# ['Christopher', 'Tucker'] 2
# ['Daniel', 'Jones'] 2
# ['Devin', 'Craig'] 2
# ['Erin', 'Prince'] 2
# ['Bernard', 'Ortiz'] 2
# ['Nicole', 'Miller'] 2
# ['Christopher', 'Fritz'] 2
# ['Bonnie', 'Mckinney'] 2
# ['Troy', 'Nelson'] 2
# ['Jennifer', 'Lee'] 2
# ['Ronald', 'Ward'] 2
# ['Nathaniel', 'Hampton'] 2
# ['Michael', 'Travis'] 2
# ['James', 'Taylor'] 2
# ['Thomas', 'Strickland'] 2
# ['Brittany', 'Jackson'] 2
# ['Marisa', 'Lowe'] 2
# ['Nicole', 'Thomas'] 2
# ['Matthew', 'Rodriguez'] 2
# ['Kent', 'Fernandez'] 2
# ['Michelle', 'Martin'] 2
# ['John', 'Sparks'] 2
# ['Ann', 'Blake'] 2
# ['Melissa', 'Miller'] 2
# ['Steven', 'Houston'] 2
# ['Kristen', 'Anderson'] 2
# ['Cory', 'Jones'] 2
# ['Jennifer', 'Mora'] 2
# ['Dennis', 'Griffin'] 2
# ['Darryl', 'Brown'] 2
# ['Martin', 'Mosley'] 2
# ['Joyce', 'Diaz'] 2
# ['Jeffrey', 'Rose'] 2
# ['Jamie', 'Moreno'] 2
# ['Catherine', 'Williams'] 2
# ['Lauren', 'Byrd'] 2
# ['Vanessa', 'Frazier'] 2
# ['Stephen', 'Bryant'] 2
# ['Lawrence', 'Liu'] 2
# ['Joseph', 'Larsen'] 2
# ['Susan', 'Collier'] 2
# ['Meagan', 'Jensen'] 2
# ['Julie', 'Harper'] 2
# ['Meghan', 'Carroll'] 2
# ['Wanda', 'Horton'] 2
# ['Mary', 'Campbell'] 2
# ['Jennifer', 'Rodgers'] 2
# ['Heather', 'Cooper'] 2
# ['Ryan', 'Perez'] 2
# ['Ryan', 'Cox'] 2
# ['Darren', 'Zavala'] 2
# ['Joseph', 'Morales', 'III'] 3
# ['Aaron', 'West'] 2
# ['James', 'Combs'] 2
# ['Curtis', 'Garner'] 2
# ['Sarah', 'Miller'] 2
# ['Samantha', 'Thomas'] 2
# ['Robert', 'Atkins'] 2
# ['Alexis', 'Crawford'] 2
# ['Ryan', 'Maddox'] 2
# ['Jonathan', 'Meyer'] 2
# ['Donna', 'Wagner'] 2
# ['William', 'Kennedy'] 2
# ['Kimberly', 'Martinez'] 2
# ['Matthew', 'Anderson'] 2
# ['Kari', 'Miller'] 2
# ['Jenna', 'Luna'] 2
# ['Justin', 'Contreras'] 2
# ['Mary', 'Fox'] 2
# ['Joseph', 'Perkins'] 2
# ['Kelly', 'Phillips'] 2
# ['Justin', 'Thornton'] 2
# ['Joshua', 'Barber'] 2
# ['Travis', 'Jackson'] 2
# ['Jordan', 'Beasley'] 2
# ['Kevin', 'Allen'] 2
# ['Victoria', 'Harris'] 2
# ['Victoria', 'Joseph'] 2
# ['Brandy', 'Marshall'] 2
# ['Ryan', 'Jimenez'] 2
# ['Michael', 'Chan'] 2
# ['Christopher', 'Phillips'] 2
# ['Kevin', 'Murphy'] 2
# ['Vanessa', 'Harper'] 2
# ['James', 'Ferguson'] 2
# ['Carol', 'Schroeder'] 2
# ['Jerry', 'Phillips'] 2
# ['Kristin', 'Wade'] 2
# ['Jessica', 'Warner'] 2
# ['Dorothy', 'Burke'] 2
# ['Bethany', 'Walter'] 2
# ['Melissa', 'Avery'] 2
# ['Daniel', 'Sutton'] 2
# ['Ryan', 'Johnson'] 2
# ['Timothy', 'Quinn'] 2
# ['Zachary', 'Allen'] 2
# ['Lauren', 'Schmitt'] 2
# ['Stephanie', 'Armstrong'] 2
# ['Ruben', 'Rivera'] 2
# ['Patricia', 'Petty'] 2
# ['Joseph', 'Jacobs'] 2
# ['Bianca', 'Wilson'] 2
# ['Donald', 'Perez'] 2
# ['Curtis', 'Gomez'] 2
# ['Courtney', 'Brown'] 2
# ['Nicole', 'Randall'] 2
# ['Steven', 'Lambert'] 2
# ['Anthony', 'Alvarez'] 2
# ['Shawn', 'Farrell'] 2
# ['Jesus', 'Schmidt'] 2
# ['Laura', 'Wright'] 2
# ['Steven', 'Smith'] 2
# ['Norman', 'Thompson'] 2
# ['Anthony', 'Wright'] 2
# ['Kayla', 'Watts'] 2
# ['Aimee', 'Johnson'] 2
# ['Heidi', 'Scott'] 2
# ['Anthony', 'Williams'] 2
# ['Sarah', 'Hill'] 2
# ['Kim', 'Wang'] 2
# ['Beth', 'Manning'] 2
# ['Ryan', 'Hanson'] 2
# ['James', 'Wood'] 2
# ['Corey', 'Greene'] 2
# ['John', 'Carter'] 2
# ['Beth', 'Garza'] 2
# ['Karen', 'Jones'] 2
# ['Stephanie', 'Poole'] 2
# ['Lisa', 'Brown'] 2
# ['Paul', 'Scott'] 2
# ['Evelyn', 'Buck'] 2
# ['Terry', 'Harrell'] 2
# ['Leah', 'Skinner'] 2
# ['Anthony', 'Mercado'] 2
# ['Walter', 'Kelly'] 2
# ['Lori', 'Evans'] 2
# ['Ashley', 'Jones'] 2
# ['Amber', 'Soto'] 2
# ['Patrick', 'Phillips'] 2
# ['Linda', 'Curry'] 2
# ['Alexander', 'Obrien'] 2
# ['Vincent', 'Garza'] 2
# ['Terry', 'Marsh'] 2
# ['Angela', 'Perkins', 'DVM'] 3
# ['Peter', 'Hampton'] 2
# ['David', 'Cross'] 2
# ['Clinton', 'Ortega'] 2
# ['Jamie', 'Escobar'] 2
# ['Sandra', 'Mason'] 2
# ['Craig', 'Cole'] 2
# ['Lisa', 'Warren'] 2
# ['Maria', 'Howard'] 2
# ['Michael', 'Porter'] 2
# ['John', 'Turner'] 2
# ['Timothy', 'Wang'] 2
# ['Amanda', 'Taylor'] 2
# ['Karen', 'Mckenzie'] 2
# ['Brandon', 'Miles'] 2
# ['Christina', 'Whitaker'] 2
# ['Nicole', 'Peterson'] 2
# ['Ashley', 'Moore'] 2
# ['Todd', 'Carrillo'] 2
# ['Robert', 'Williams'] 2
# ['Ashley', 'Jones'] 2
# ['Vanessa', 'Parker'] 2
# ['Robert', 'Carlson'] 2
# ['Jared', 'Lewis'] 2
# ['Christopher', 'Hernandez'] 2
# ['Kimberly', 'Harris'] 2
# ['Katrina', 'Hill'] 2
# ['Heather', 'Lee'] 2
# ['Donald', 'Harmon'] 2
# ['Elizabeth', 'Sanders'] 2
# ['Richard', 'Ramsey'] 2
# ['Carmen', 'Johnson'] 2
# ['Elaine', 'Osborne'] 2
# ['Kent', 'Burns'] 2
# ['Meagan', 'Smith'] 2
# ['Craig', 'Hahn'] 2
# ['Jeremy', 'Wu'] 2
# ['Aaron', 'Rodriguez'] 2
# ['Matthew', 'Taylor'] 2
# ['Diana', 'Evans'] 2
# ['Michele', 'Pearson'] 2
# ['Erik', 'Wagner'] 2
# ['Maria', 'Welch'] 2
# ['Debra', 'Martin'] 2
# ['Devon', 'Conner'] 2
# ['Christine', 'Patel'] 2
# ['David', 'Lopez'] 2
# ['Nathan', 'Baird'] 2
# ['Samuel', 'Castillo'] 2
# ['Rebecca', 'Payne'] 2
# ['Carl', 'Johnson'] 2
# ['William', 'Adams'] 2
# ['Paula', 'Harrison'] 2
# ['Wayne', 'Atkinson'] 2
# ['Lindsay', 'Frank'] 2
# ['Jose', 'Garcia'] 2
# ['Andrew', 'Gaines'] 2
# ['Rachael', 'Liu'] 2
# ['Donald', 'Lewis'] 2
# ['Shane', 'Edwards'] 2
# ['Todd', 'Levy'] 2
# ['Joanna', 'Moore'] 2
# ['Michael', 'Lewis'] 2
# ['James', 'Robinson'] 2
# ['Jeffrey', 'Arellano'] 2
# ['Heather', 'Allen', 'MD'] 3
# ['Lori', 'Villarreal'] 2
# ['Robert', 'Harper'] 2
# ['Karen', 'Villegas'] 2
# ['Tracey', 'Crane'] 2
# ['Elizabeth', 'Allen'] 2
# ['Jorge', 'Lynn'] 2
# ['Harold', 'Gordon'] 2
# ['Nicholas', 'Mcclain'] 2
# ['Tanya', 'Harris'] 2
# ['Amy', 'Smith'] 2
# ['Kathy', 'Morse'] 2
# ['Andrea', 'Wood'] 2
# ['Maureen', 'Massey'] 2
# ['Daniel', 'Smith'] 2
# ['Alexandra', 'Smith'] 2
# ['Caitlin', 'Hall'] 2
# ['Jose', 'Carlson'] 2
# ['Deborah', 'Macias'] 2
# ['Dwayne', 'Rice'] 2
# ['Matthew', 'Harris'] 2
# ['Eric', 'Bowman'] 2
# ['Samuel', 'Ali'] 2
# ['David', 'Miller'] 2
# ['James', 'Moreno'] 2
# ['Brooke', 'Austin'] 2
# ['Alisha', 'Martin'] 2
# ['Neil', 'Rodriguez'] 2
# ['Gary', 'Williams'] 2
# ['Michael', 'Pittman'] 2
# ['Stephanie', 'Palmer'] 2
# ['Christine', 'Perry'] 2
# ['Suzanne', 'David'] 2
# ['Amber', 'Smith'] 2
# ['Ryan', 'Jones'] 2
# ['Emily', 'Ford'] 2
# ['Kelsey', 'Shea'] 2
# ['Katherine', 'Wallace'] 2
# ['Erica', 'Conway'] 2
# ['Tyler', 'Parker'] 2
# ['Michael', 'Parks'] 2
# ['Elizabeth', 'Hunt'] 2
# ['Grant', 'Jackson'] 2
# ['Daniel', 'Matthews'] 2
# ['Diana', 'Silva'] 2
# ['Frank', 'Garza'] 2
# ['Terri', 'Fischer'] 2
# ['Robert', 'Goodwin'] 2
# ['Bobby', 'Ruiz'] 2
# ['Stephanie', 'Taylor'] 2
# ['Erin', 'Hill'] 2
# ['Erin', 'Cohen'] 2
# ['Jeffrey', 'Morris'] 2
# ['Elizabeth', 'Simpson'] 2
# ['Jennifer', 'Davis'] 2
# ['Rachel', 'Burton'] 2
# ['Joseph', 'Wilkins'] 2
# ['Lawrence', 'Montgomery'] 2
# ['Patricia', 'Howard'] 2
# ['Jessica', 'Hanson'] 2
# ['Donna', 'Dean'] 2
# ['Edwin', 'Reid'] 2
# ['Jodi', 'Brown'] 2
# ['Elizabeth', 'Richard'] 2
# ['Aaron', 'Martinez'] 2
# ['Stephen', 'Fischer'] 2
# ['Diana', 'Reeves'] 2
# ['Jeffrey', 'Eaton'] 2
# ['Evelyn', 'Miller'] 2
# ['Christopher', 'Kidd'] 2
# ['Sarah', 'Adams'] 2
# ['Melinda', 'Nelson'] 2
# ['Kevin', 'Brooks'] 2
# ['John', 'Bowen'] 2
# ['Tracie', 'Abbott'] 2
# ['Allen', 'Foster'] 2
# ['Kathryn', 'Elliott'] 2
# ['Christopher', 'Walker'] 2
# ['Cynthia', 'Martin'] 2
# ['Amanda', 'Bennett'] 2
# ['Dennis', 'Padilla'] 2
# ['Antonio', 'Miller'] 2
# ['Melissa', 'Trevino'] 2
# ['Andrew', 'King'] 2
# ['John', 'Martinez'] 2
# ['Lauren', 'King'] 2
# ['Stephanie', 'Mercado'] 2
# ['William', 'Smith'] 2
# ['Jonathan', 'Marshall'] 2
# ['Luke', 'Lowery', 'MD'] 3
# ['Emily', 'Reynolds'] 2
# ['Kevin', 'Mclean'] 2
# ['Elizabeth', 'Taylor'] 2
# ['Pamela', 'Rivas'] 2
# ['Tammy', 'Martin'] 2
# ['Holly', 'Watkins'] 2
# ['Patrick', 'Chen'] 2
# ['Michelle', 'Griffin'] 2
# ['Theresa', 'Andrews'] 2
# ['Alan', 'Henry'] 2
# ['Dr.', 'Larry', 'Hines'] 3
# ['Travis', 'Frazier'] 2
# ['Julie', 'Jones'] 2
# ['Natalie', 'Reynolds'] 2
# ['Jessica', 'Cohen'] 2
# ['Jason', 'Robinson'] 2
# ['Heather', 'Palmer'] 2
# ['Emily', 'Cardenas', 'MD'] 3
# ['Scott', 'Glover'] 2
# ['Jacqueline', 'White'] 2
# ['Mrs.', 'Elizabeth', 'Espinoza', 'DDS'] 4
# ['Toni', 'Porter'] 2
# ['Jennifer', 'Mejia'] 2
# ['Brenda', 'Peterson'] 2
# ['Paul', 'Hamilton'] 2
# ['Patricia', 'Nguyen'] 2
# ['James', 'Ho'] 2
# ['Elizabeth', 'Cohen'] 2
# ['Stephanie', 'Lane'] 2
# ['Dawn', 'Rhodes'] 2
# ['Theresa', 'Robinson'] 2
# ['Breanna', 'Mosley'] 2
# ['Carmen', 'Wilson'] 2
# ['Ian', 'Brown'] 2
# ['Kathleen', 'Matthews'] 2
# ['Bryan', 'Diaz'] 2
# ['Gina', 'Sweeney'] 2
# ['Alan', 'Garcia'] 2
# ['Erik', 'Wheeler'] 2
# ['Stephanie', 'Robles'] 2
# ['Samantha', 'Hanson'] 2
# ['Christopher', 'Williams'] 2
# ['Stephanie', 'Hart'] 2
# ['Mrs.', 'Lisa', 'Becker'] 3
# ['Bianca', 'Johnson'] 2
# ['Amy', 'Steele'] 2
# ['Gina', 'Contreras'] 2
# ['Jaime', 'Alexander'] 2
# ['Kevin', 'Coleman'] 2
# ['Caitlin', 'Williams'] 2
# ['Joseph', 'Lloyd'] 2
# ['Carrie', 'Hernandez'] 2
# ['Mr.', 'Travis', 'Young'] 3
# ['Francis', 'Wright'] 2
# ['Joel', 'Harper'] 2
# ['Eduardo', 'Park'] 2
# ['Melissa', 'Yoder'] 2
# ['Donna', 'Campbell'] 2
# ['Connie', 'Delacruz'] 2
# ['Luis', 'Parker'] 2
# ['Pamela', 'Watts'] 2
# ['Lindsey', 'Mitchell'] 2
# ['Brenda', 'Price'] 2
# ['Joseph', 'Howard'] 2
# ['Amy', 'Evans'] 2
# ['Paula', 'Fernandez', 'DVM'] 3
# ['Amber', 'Cunningham'] 2
# ['Preston', 'Wheeler'] 2
# ['James', 'Lopez'] 2
# ['Chad', 'Drake'] 2
# ['Samuel', 'Blackburn'] 2
# ['Shawn', 'Nielsen'] 2
# ['Eric', 'Perez'] 2
# ['Kevin', 'Montgomery'] 2
# ['Terry', 'Thomas'] 2
# ['Kim', 'Meyer'] 2
# ['Michael', 'Townsend'] 2
# ['Ronnie', 'Rodriguez'] 2
# ['Savannah', 'Smith'] 2
# ['Shane', 'Nguyen'] 2
# ['Michael', 'Brown'] 2
# ['Robert', 'Young'] 2
# ['Daniel', 'Griffin'] 2
# ['James', 'Johnson'] 2
# ['Mary', 'Cox'] 2
# ['Tina', 'Aguirre'] 2
# ['Jillian', 'Mcdonald'] 2
# ['Matthew', 'Branch'] 2
# ['Christopher', 'Jordan'] 2
# ['Victor', 'Mcguire'] 2
# ['Erin', 'Arnold'] 2
# ['Nicholas', 'Wu'] 2
# ['Kristen', 'Wilson'] 2
# ['Morgan', 'Moore'] 2
# ['Stephen', 'Smith'] 2
# ['Jeremy', 'Romero'] 2
# ['Julie', 'Bush'] 2
# ['Brittany', 'Taylor'] 2
# ['James', 'Kim'] 2
# ['Ashley', 'Roberts'] 2
# ['Brandon', 'Johnson'] 2
# ['David', 'Davenport'] 2
# ['Mark', 'Washington'] 2
# ['Alicia', 'Marshall'] 2
# ['Barbara', 'Santana'] 2
# ['Samantha', 'Parker'] 2
# ['Joseph', 'Walters'] 2
# ['Michael', 'Zamora'] 2
# ['Kyle', 'Cobb'] 2
# ['Jill', 'Clark'] 2
# ['Sarah', 'Warren'] 2
# ['Jennifer', 'Robinson'] 2
# ['Patricia', 'Johnson'] 2
# ['Henry', 'Evans'] 2
# ['Alexander', 'Ramsey'] 2
# ['Brandon', 'Stephens'] 2
# ['Jeff', 'Holland'] 2
# ['Samuel', 'Schultz'] 2
# ['Brett', 'Johnson'] 2
# ['Daniel', 'Sherman'] 2
# ['Justin', 'Mccall'] 2
# ['Jonathan', 'Evans'] 2
# ['Jacqueline', 'Kennedy'] 2
# ['Martin', 'Stephenson'] 2
# ['Lindsey', 'Lane'] 2
# ['Jessica', 'Hart'] 2
# ['Edward', 'Lucas'] 2
# ['Lisa', 'Osborne'] 2
# ['Hannah', 'Black'] 2
# ['Alexander', 'Paul'] 2
# ['Brenda', 'Wong'] 2
# ['Thomas', 'Delgado'] 2
# ['Jeremy', 'Sutton'] 2
# ['Paula', 'Donaldson'] 2
# ['Valerie', 'Thompson'] 2
# ['John', 'Schaefer'] 2
# ['Jesus', 'Manning'] 2
# ['Tyrone', 'Lawson'] 2
# ['Carl', 'May'] 2
# ['Brittany', 'Russell'] 2
# ['Philip', 'Edwards'] 2
# ['Robert', 'Aguilar'] 2
# ['Aaron', 'Russo'] 2
# ['Tracy', 'Andrade'] 2
# ['Amy', 'Sullivan'] 2
# ['Howard', 'Beck'] 2
# ['Dr.', 'Xavier', 'Bell', 'II'] 4
# ['Dawn', 'Schultz'] 2
# ['Caleb', 'Lucas'] 2
# ['Barbara', 'Gonzalez'] 2
# ['Charles', 'Yang'] 2
# ['David', 'Gallagher'] 2
# ['Bethany', 'Vargas'] 2
# ['Jennifer', 'Schultz'] 2
# ['Paula', 'Marshall'] 2
# ['Jordan', 'Elliott'] 2
# ['Samantha', 'Mcmillan'] 2
# ['Judith', 'Johnson'] 2
# ['Grace', 'Palmer'] 2
# ['Brandon', 'Ramirez'] 2
# ['Carol', 'Smith'] 2
# ['Matthew', 'Odom'] 2
# ['Erika', 'Gray'] 2
# ['Donna', 'Kramer'] 2
# ['Jonathan', 'Snyder'] 2
# ['Frank', 'Howe'] 2
# ['Amy', 'Beck'] 2
# ['Lori', 'Holmes'] 2
# ['Rebekah', 'Hampton'] 2
# ['Perry', 'Bishop'] 2
# ['Andrew', 'Hanson', 'MD'] 3
# ['Jody', 'Hughes'] 2
# ['Anna', 'Garcia'] 2
# ['Colleen', 'Walker'] 2
# ['Danny', 'Bridges'] 2
# ['Kristina', 'Ford'] 2
# ['Sabrina', 'Davidson'] 2
# ['Alexander', 'Freeman'] 2
# ['Jack', 'Davis'] 2
# ['Victor', 'Rivera'] 2
# ['Elizabeth', 'Pena'] 2
# ['Neil', 'Castro'] 2
# ['Michael', 'Briggs'] 2
# ['Anna', 'Andersen'] 2
# ['Elizabeth', 'Oconnor'] 2
# ['Zachary', 'Brooks'] 2
# ['Scott', 'Jackson'] 2
# ['Mary', 'Fuentes'] 2
# ['Denise', 'Reyes'] 2
# ['Janice', 'Collier'] 2
# ['Tina', 'Barber'] 2
# ['Keith', 'Rojas'] 2
# ['Michelle', 'Decker'] 2
# ['James', 'Smith'] 2
# ['Alexandra', 'Thompson'] 2
# ['Jacqueline', 'Campbell'] 2
# ['Austin', 'Clark'] 2
# ['Brooke', 'Thomas'] 2
# ['Molly', 'Smith'] 2
# ['Pamela', 'Beck'] 2
# ['Timothy', 'Morris'] 2
# ['Lauren', 'White'] 2
# ['Jessica', 'Beltran'] 2
# ['Alexandra', 'Jones'] 2
# ['Evelyn', 'Rice'] 2
# ['Stephen', 'Ellis'] 2
# ['Caroline', 'Smith'] 2
# ['Fred', 'Case'] 2
# ['Crystal', 'Anderson'] 2
# ['Jordan', 'Gross'] 2
# ['Marie', 'Harris'] 2
# ['Charles', 'Hayes'] 2
# ['Beverly', 'Sheppard'] 2
# ['Denise', 'Solis'] 2
# ['Alexander', 'Myers'] 2
# ['Sally', 'Robertson'] 2
# ['Steven', 'Morris'] 2
# ['Nina', 'Flores'] 2
# ['Miguel', 'Patterson'] 2
# ['John', 'Simpson'] 2
# ['Charles', 'Cruz'] 2
# ['Monica', 'Davis'] 2
# ['James', 'Fields'] 2
# ['Kevin', 'Frederick'] 2
# ['Jeremy', 'Soto'] 2
# ['Ronald', 'Harris'] 2
# ['Carol', 'Stewart'] 2
# ['Albert', 'Durham'] 2
# ['James', 'Sanchez'] 2
# ['John', 'Adams'] 2
# ['Cody', 'Williams'] 2
# ['Ernest', 'Love'] 2
# ['Tommy', 'Smith'] 2
# ['Jared', 'Anderson'] 2
# ['Jennifer', 'Yang'] 2
# ['Joe', 'Mercado'] 2
# ['Mr.', 'Roberto', 'Wright', 'MD'] 4
# ['Michael', 'Smith'] 2
# ['William', 'Park'] 2
# ['Benjamin', 'Williams'] 2
# ['Dean', 'Perez'] 2
# ['Mr.', 'Dale', 'Miller'] 3
# ['Marissa', 'Russell'] 2
# ['Mary', 'Gonzalez', 'DDS'] 3
# ['April', 'Jackson'] 2
# ['William', 'Hayes'] 2
# ['Meghan', 'Holloway'] 2
# ['Amy', 'Coleman'] 2
# ['James', 'Green'] 2
# ['Michael', 'Tran'] 2
# ['Joseph', 'Cortez'] 2
# ['Anita', 'Moss'] 2
# ['Benjamin', 'Stokes'] 2
# ['Michael', 'Li'] 2
# ['Alexander', 'Rosales'] 2
# ['Katie', 'Dawson'] 2
# ['Shelly', 'Erickson'] 2
# ['Kathryn', 'Turner'] 2
# ['Jacob', 'Lee'] 2
# ['Ryan', 'Smith'] 2
# ['Joshua', 'Fernandez'] 2
# ['Mia', 'Roach'] 2
# ['William', 'Rodriguez'] 2
# ['Wanda', 'Cruz'] 2
# ['Pamela', 'Hall'] 2
# ['David', 'Smith'] 2
# ['Jason', 'Brown'] 2
# ['Chelsea', 'Alexander'] 2
# ['Kimberly', 'Tate'] 2
# ['Daniel', 'Williams'] 2
# ['Terri', 'Jacobson'] 2
# ['Paul', 'Harris'] 2
# ['Jessica', 'Thompson'] 2
# ['Nancy', 'Hawkins'] 2
# ['Deborah', 'Phillips'] 2
# ['Mark', 'Mendoza'] 2
# ['Stephen', 'Williamson'] 2
# ['Jennifer', 'Strong'] 2
# ['Matthew', 'Moore'] 2
# ['Raymond', 'Parker'] 2
# ['Lee', 'Evans'] 2
# ['Curtis', 'Rodriguez'] 2
# ['Sara', 'Morris'] 2
# ['Dawn', 'Palmer'] 2
# ['Brianna', 'Benson'] 2
# ['Luis', 'Watts'] 2
# ['Mrs.', 'Cindy', 'Brown'] 3
# ['Summer', 'Sandoval'] 2
# ['Ashley', 'Smith'] 2
# ['Randy', 'Wallace'] 2
# ['Angela', 'Simmons'] 2
# ['Sandra', 'Haley'] 2
# ['George', 'Morgan'] 2
# ['Melissa', 'Ali'] 2
# ['Matthew', 'Oliver'] 2
# ['Michael', 'Kirk'] 2
# ['Terry', 'Khan'] 2
# ['Kristie', 'Elliott'] 2
# ['Joel', 'Campbell'] 2
# ['Anthony', 'Henderson'] 2
# ['Brent', 'Christensen'] 2
# ['Heidi', 'Hayes'] 2
# ['Ryan', 'Mcbride'] 2
# ['Kyle', 'Murillo'] 2
# ['Angela', 'Powell'] 2
# ['Jeanette', 'Simmons'] 2
# ['Adam', 'Vance'] 2
# ['Kristen', 'Murray'] 2
# ['Jessica', 'Burnett'] 2
# ['Alex', 'Walker'] 2
# ['Robert', 'Phillips'] 2
# ['Elizabeth', 'Martinez'] 2
# ['Kristina', 'Young'] 2
# ['Sarah', 'Morgan'] 2
# ['Cheryl', 'Harding'] 2
# ['Keith', 'Hunter'] 2
# ['Todd', 'Williams'] 2
# ['James', 'White', 'MD'] 3
# ['Kyle', 'Johnson'] 2
# ['Andrea', 'Suarez'] 2
# ['Michael', 'Sanchez'] 2
# ['Jaime', 'Torres'] 2
# ['Donald', 'Gill', 'DDS'] 3
# ['Austin', 'Lee'] 2
# ['Adrian', 'Bowman'] 2
# ['Julie', 'Perez'] 2
# ['Debra', 'Maxwell'] 2
# ['Bradley', 'Phillips'] 2
# ['Sonya', 'Simmons'] 2
# ['Eric', 'Miller'] 2
# ['Charles', 'Berger'] 2
# ['Mary', 'Monroe'] 2
# ['Destiny', 'Burns'] 2
# ['Patrick', 'Khan'] 2
# ['Nathaniel', 'Henson'] 2
# ['Larry', 'Miller'] 2
# ['Timothy', 'French'] 2
# ['Xavier', 'Mitchell'] 2
# ['Jason', 'Crosby'] 2
# ['Joshua', 'Johnson'] 2
# ['Alyssa', 'Clark'] 2
# ['Jonathan', 'Cooper'] 2
# ['Mark', 'Hunt'] 2
# ['Norman', 'Moore'] 2
# ['Brian', 'Atkins'] 2
# ['Zachary', 'Jones'] 2
# ['Danielle', 'Wong'] 2
# ['Patricia', 'Lane'] 2
# ['Joshua', 'Rose'] 2
# ['Hannah', 'Montes'] 2
# ['Mrs.', 'Catherine', 'Williams', 'MD'] 4
# ['Michael', 'Jenkins'] 2
# ['James', 'Scott'] 2
# ['Evan', 'Ballard'] 2
# ['Andrea', 'Miller'] 2
# ['Jasmine', 'Lynch'] 2
# ['Jennifer', 'Fox'] 2
# ['Jared', 'Castro'] 2
# ['Eugene', 'Cox'] 2
# ['Wendy', 'Wilson'] 2
# ['Debbie', 'Smith'] 2
# ['Michael', 'Fletcher'] 2
# ['Jay', 'Waters'] 2
# ['Melissa', 'Martinez'] 2
# ['Cory', 'Howard'] 2
# ['Mitchell', 'Hanson'] 2
# ['Corey', 'Boyer'] 2
# ['Elizabeth', 'Gonzalez'] 2
# ['Robert', 'Hutchinson'] 2
# ['David', 'Hernandez'] 2
# ['Tammy', 'Jordan'] 2
# ['Denise', 'Johnson'] 2
# ['Brandi', 'Copeland'] 2
# ['Evan', 'Marshall'] 2
# ['Gregory', 'Long'] 2
# ['Kristen', 'Underwood'] 2
# ['Walter', 'French'] 2
# ['Edwin', 'Thompson'] 2
# ['Edward', 'Rivera'] 2
# ['Brandon', 'Wilson'] 2
# ['Alejandra', 'Todd'] 2
# ['Dana', 'Hoffman'] 2
# ['David', 'Howard'] 2
# ['Ashley', 'Caldwell', 'MD'] 3
# ['Cindy', 'Horn'] 2
# ['Kevin', 'Armstrong'] 2
# ['Stacey', 'Porter'] 2
# ['Patrick', 'Hunt'] 2
# ['David', 'White'] 2
# ['Tammy', 'Black'] 2
# ['Joanna', 'Williams'] 2
# ['Becky', 'Moran'] 2
# ['Brenda', 'Smith'] 2
# ['Gabrielle', 'Webb'] 2
# ['Mr.', 'Jared', 'Campbell'] 3
# ['Ryan', 'Jenkins'] 2
# ['Thomas', 'Shepard'] 2
# ['Jeremiah', 'Boyd'] 2
# ['Matthew', 'White'] 2
# ['Christina', 'Anderson'] 2
# ['Edward', 'Olson'] 2
# ['Emily', 'Bryant'] 2
# ['Amy', 'Guzman'] 2
# ['Kathleen', 'Owens'] 2
# ['John', 'Davila'] 2
# ['Nicole', 'King'] 2
# ['Jason', 'Villarreal'] 2
# ['Matthew', 'Washington'] 2
# ['Peter', 'Simpson'] 2
# ['Cristian', 'Espinoza'] 2
# ['Steven', 'Fry'] 2
# ['David', 'Miller'] 2
# ['Tamara', 'Hernandez'] 2
# ['Jordan', 'Lewis'] 2
# ['Carol', 'Anderson'] 2
# ['Michael', 'Moreno', 'PhD'] 3
# ['Nicholas', 'Logan'] 2
# ['Paul', 'Anderson'] 2
# ['Jason', 'Young'] 2
# ['Wesley', 'Martin'] 2
# ['Karen', 'Wall'] 2
# ['Tara', 'Parker', 'MD'] 3
# ['Michael', 'Reyes'] 2
# ['Amy', 'Henderson'] 2
# ['Jessica', 'Reed'] 2
# ['Joseph', 'Miranda'] 2
# ['Mackenzie', 'Jones'] 2
# ['Jon', 'Espinoza'] 2
# ['Kelly', 'Medina'] 2
# ['Jason', 'Rubio'] 2
# ['Jennifer', 'Munoz'] 2
# ['Christopher', 'Warner'] 2
# ['Vincent', 'Thomas'] 2
# ['Andrew', 'Young'] 2
# ['David', 'Jenkins'] 2
# ['Daniel', 'Stephens'] 2
# ['Elizabeth', 'Lewis'] 2
# ['Aaron', 'Moore'] 2
# ['Lisa', 'Hogan'] 2
# ['Shawn', 'Williams', 'DVM'] 3
# ['Michele', 'Dickerson'] 2
# ['Dr.', 'Alicia', 'Martinez'] 3
# ['Mr.', 'Timothy', 'Anderson'] 3
# ['Sierra', 'Jackson'] 2
# ['Sharon', 'Taylor'] 2
# ['Jeffrey', 'Smith'] 2
# ['Mark', 'Taylor'] 2
# ['Christina', 'Ross'] 2
# ['Judy', 'Hall'] 2
# ['Jennifer', 'Fox'] 2
# ['Kenneth', 'Moran'] 2
# ['Gerald', 'Ferguson'] 2
# ['Albert', 'Carter'] 2
# ['Michael', 'Reilly'] 2
# ['Kathleen', 'Schwartz'] 2
# ['Stacey', 'Harris'] 2
# ['Mrs.', 'Paula', 'Lee'] 3
# ['Adrian', 'Black'] 2
# ['Rita', 'Moreno'] 2
# ['Jason', 'Perry'] 2
# ['Scott', 'Ortiz'] 2
# ['Randy', 'Mueller'] 2
# ['Samantha', 'Anderson'] 2
# ['Phillip', 'Brown'] 2
# ['Christina', 'Kerr'] 2
# ['Derrick', 'Hill'] 2
# ['Nathan', 'Bond'] 2
# ['Marie', 'Wilson'] 2
# ['Caitlin', 'Jones'] 2
# ['Barbara', 'Campbell'] 2
# ['Katie', 'Gonzales'] 2
# ['Mr.', 'Elijah', 'Hall'] 3
# ['James', 'Sanders'] 2
# ['Nicholas', 'Martinez'] 2
# ['Maria', 'Mack'] 2
# ['Mary', 'Mason'] 2
# ['Tiffany', 'Campbell'] 2
# ['Mr.', 'Raymond', 'Stone'] 3
# ['Dominique', 'Henderson'] 2
# ['Martin', 'Williams'] 2
# ['Hannah', 'Parker'] 2
# ['Susan', 'Webb'] 2
# ['Rachel', 'Johnson'] 2
# ['Darren', 'Davis'] 2
# ['Tim', 'Carr'] 2
# ['Jesus', 'Ryan'] 2
# ['John', 'Hays'] 2
# ['Scott', 'Stewart'] 2
# ['Alexandra', 'Roberts'] 2
# ['Amanda', 'Norman'] 2
# ['James', 'Moody'] 2
# ['Brenda', 'Jones'] 2
# ['Kathy', 'Smith'] 2
# ['Raymond', 'Clark'] 2
# ['Ashley', 'Martin'] 2
# ['Tamara', 'Flowers'] 2
# ['Cesar', 'Hanson'] 2
# ['Ross', 'Strickland'] 2
# ['Randy', 'Moore'] 2
# ['Henry', 'Andersen'] 2
# ['Paul', 'Martin'] 2
# ['Sarah', 'Stanley'] 2
# ['Jordan', 'Lewis'] 2
# ['Ashley', 'Richardson'] 2
# ['Michael', 'Brown'] 2
# ['Jason', 'Davis'] 2
# ['Wendy', 'Mcclain'] 2
# ['Troy', 'Williams'] 2
# ['Carrie', 'Alexander'] 2
# ['Kyle', 'Ware'] 2
# ['Michael', 'Robinson'] 2
# ['Roger', 'Wilson'] 2
# ['Teresa', 'Fuller'] 2
# ['Craig', 'Silva'] 2
# ['Duane', 'Thomas'] 2
# ['Jon', 'Crosby'] 2
# ['Jon', 'Steele'] 2
# ['Daniel', 'Shaw'] 2
# ['Gwendolyn', 'Williams'] 2
# ['Angela', 'Hess'] 2
# ['Cameron', 'Arnold'] 2
# ['Janice', 'Garcia'] 2
# ['Anne', 'Bullock'] 2
# ['Katie', 'Moody'] 2
# ['Kayla', 'Rivas'] 2
# ['Danny', 'Pearson'] 2
# ['Billy', 'Robles'] 2
# ['Michelle', 'Delgado'] 2
# ['Cindy', 'Harrison'] 2
# ['John', 'Dickerson', 'MD'] 3
# ['Tina', 'Armstrong'] 2
# ['Mr.', 'Alex', 'Franklin'] 3
# ['Ryan', 'King'] 2
# ['Christine', 'Guzman'] 2
# ['Helen', 'Malone'] 2
# ['Benjamin', 'Carpenter'] 2
# ['Mrs.', 'Jessica', 'Dunn'] 3
# ['Jessica', 'Kaiser'] 2
# ['Brandon', 'Black'] 2
# ['David', 'Hernandez'] 2
# ['Brenda', 'Turner'] 2
# ['Katherine', 'Black'] 2
# ['Larry', 'Santos'] 2
# ['Zachary', 'Dominguez'] 2
# ['Tanya', 'Fernandez'] 2
# ['Joseph', 'Nichols'] 2
# ['Rebecca', 'Martinez'] 2
# ['Traci', 'Ramirez'] 2
# ['Ryan', 'Bauer'] 2
# ['Joshua', 'Williams'] 2
# ['Devon', 'Foley'] 2
# ['Heidi', 'Walter'] 2
# ['Mario', 'Nguyen'] 2
# ['Jordan', 'Hernandez'] 2
# ['William', 'Miller'] 2
# ['Nicholas', 'Chung'] 2
# ['Christine', 'Cooley'] 2
# ['Carrie', 'Nelson'] 2
# ['Crystal', 'Fowler'] 2
# ['Lori', 'Taylor'] 2
# ['Mr.', 'Michael', 'Stevenson'] 3
# ['Matthew', 'Holmes'] 2
# ['David', 'Walls'] 2
# ['Megan', 'Martin'] 2
# ['Karen', 'Peterson'] 2
# ['Kristen', 'Wallace'] 2
# ['Mark', 'Peterson'] 2
# ['Jason', 'Jones', 'DDS'] 3
# ['Keith', 'Barber'] 2
# ['Patrick', 'Green'] 2
# ['Antonio', 'Lopez'] 2
# ['Travis', 'Peterson'] 2
# ['Gabriel', 'Hunter'] 2
# ['Amanda', 'Ross'] 2
# ['Samuel', 'Thompson'] 2
# ['Robert', 'Bowman'] 2
# ['Cynthia', 'Cox'] 2
# ['Brittany', 'Miller'] 2
# ['Eric', 'Torres'] 2
# ['Sandra', 'Calhoun'] 2
# ['Jacob', 'Bailey'] 2
# ['Jessica', 'Harris'] 2
# ['Molly', 'Carr'] 2
# ['Keith', 'Davis'] 2
# ['Adriana', 'Wade', 'MD'] 3
# ['Elizabeth', 'Fernandez'] 2
# ['Theresa', 'Young'] 2
# ['Ruth', 'Garcia'] 2
# ['Robin', 'Mccoy'] 2
# ['Ana', 'Schmidt'] 2
# ['Amanda', 'Shelton'] 2
# ['John', 'Bryant'] 2
# ['Kristin', 'Zimmerman'] 2
# ['Marie', 'Green'] 2
# ['Cindy', 'Williams'] 2
# ['Cynthia', 'Bryan'] 2
# ['Mario', 'Horne'] 2
# ['Erin', 'Mitchell'] 2
# ['Thomas', 'Bush'] 2
# ['Kayla', 'Watkins'] 2
# ['Erica', 'Hurley', 'MD'] 3
# ['Anthony', 'Stanley'] 2
# ['Cassandra', 'Fox'] 2
# ['Christina', 'Cox'] 2
# ['Megan', 'Higgins'] 2
# ['Daniel', 'Ward'] 2
# ['Gary', 'Ray'] 2
# ['Jill', 'Salazar'] 2
# ['Joshua', 'Reed'] 2
# ['Michael', 'Crosby'] 2
# ['David', 'Lewis'] 2
# ['Todd', 'Cunningham'] 2
# ['Amber', 'Curry'] 2
# ['Nicole', 'Shepherd'] 2
# ['Karl', 'Woods'] 2
# ['Dennis', 'Rodriguez'] 2
# ['Ashley', 'Rangel'] 2
# ['Desiree', 'Green'] 2
# ['Kurt', 'Hopkins'] 2
# ['Emma', 'Brown'] 2
# ['Patrick', 'Williams'] 2
# ['Charles', 'Leonard'] 2
# ['Seth', 'Smith'] 2
# ['Jason', 'Walsh'] 2
# ['Heather', 'Wagner'] 2
# ['Rickey', 'Ramirez'] 2
# ['Dr.', 'Garrett', 'Wright'] 3
# ['Peter', 'Robinson'] 2
# ['Alex', 'Haas'] 2
# ['Justin', 'Jones'] 2
# ['Benjamin', 'Cordova'] 2
# ['William', 'Salinas'] 2
# ['Jacob', 'Lopez'] 2
# ['Matthew', 'Valenzuela'] 2
# ['Paul', 'Mcdonald'] 2
# ['Michael', 'Reynolds'] 2
# ['Tracy', 'Lowery'] 2
# ['Cory', 'Bailey'] 2
# ['James', 'Randolph'] 2
# ['Katherine', 'Stewart'] 2
# ['Billy', 'Dalton'] 2
# ['Sara', 'Kerr'] 2
# ['Sarah', 'Booker'] 2
# ['Tina', 'Compton'] 2
# ['Scott', 'Solis'] 2
# ['Jesus', 'Benton'] 2
# ['Adam', 'Harrison'] 2
# ['Jacob', 'Byrd'] 2
# ['Alison', 'Odonnell'] 2
# ['Carlos', 'Preston'] 2
# ['Randy', 'Jones'] 2
# ['Daniel', 'Gray'] 2
# ['James', 'Foster'] 2
# ['David', 'Rivera'] 2
# ['Jessica', 'Porter'] 2
# ['Jenny', 'Cortez'] 2
# ['Anne', 'Williams'] 2
# ['Joshua', 'Andrade'] 2
# ['Martin', 'Smith'] 2
# ['Laurie', 'Wright'] 2
# ['Manuel', 'Turner'] 2
# ['Brett', 'Young'] 2
# ['Brady', 'Acosta'] 2
# ['William', 'Brown'] 2
# ['Amanda', 'Carter'] 2
# ['Adam', 'Oneill'] 2
# ['Mr.', 'James', 'Allen'] 3
# ['Joseph', 'Carpenter'] 2
# ['Thomas', 'Kline'] 2
# ['Jacqueline', 'Lee'] 2
# ['Andre', 'Cooper'] 2
# ['Mr.', 'Timothy', 'Harper', 'MD'] 4
# ['Zoe', 'Mcmillan'] 2
# ['Donna', 'Burke'] 2
# ['Suzanne', 'Rivers'] 2
# ['David', 'Sexton'] 2
# ['Michelle', 'Bailey'] 2
# ['Pam', 'Burke'] 2
# ['Frederick', 'Adams'] 2
# ['Michael', 'Lewis'] 2
# ['Jason', 'Lewis'] 2
# ['Antonio', 'Jimenez'] 2
# ['Ryan', 'Burns'] 2
# ['Lynn', 'Hill'] 2
# ['Misty', 'Stewart'] 2
# ['Renee', 'Wolf'] 2
# ['Meredith', 'Tucker'] 2
# ['John', 'Evans'] 2
# ['Nichole', 'Lopez'] 2
# ['Adam', 'Wall'] 2
# ['Brittany', 'Wilson'] 2
# ['Crystal', 'Smith'] 2
# ['Robert', 'Maynard'] 2
# ['Angela', 'Brown'] 2
# ['Traci', 'Pearson'] 2
# ['Jeremy', 'Beasley'] 2
# ['Patricia', 'Warner'] 2
# ['Thomas', 'Mcconnell'] 2
# ['Bradley', 'King'] 2
# ['Dale', 'Brown', 'MD'] 3
# ['George', 'Clark'] 2
# ['Mikayla', 'Odom'] 2
# ['Matthew', 'Ortega'] 2
# ['Ricardo', 'Wells'] 2
# ['David', 'Castillo'] 2
# ['Lauren', 'Jones'] 2
# ['Morgan', 'Ramos'] 2
# ['Justin', 'Hill'] 2
# ['Eric', 'Dickerson'] 2
# ['Benjamin', 'Dixon'] 2
# ['Jeremiah', 'Davenport'] 2
# ['Michele', 'Miller'] 2
# ['Paul', 'Perry'] 2
# ['Kim', 'Schmitt'] 2
# ['Xavier', 'Cole'] 2
# ['Lindsay', 'Patterson'] 2
# ['Emily', 'Rasmussen'] 2
# ['Breanna', 'Farmer'] 2
# ['Nicole', 'Mendoza'] 2
# ['Robin', 'Kirby'] 2
# ['Ashley', 'Dougherty'] 2
# ['Anita', 'Fletcher'] 2
# ['Melissa', 'Lucas'] 2
# ['Danielle', 'Ellis'] 2
# ['James', 'Brown'] 2
# ['Monique', 'Schultz'] 2
# ['Jeffrey', 'Chang'] 2
# ['John', 'Allen'] 2
# ['Rachel', 'Chandler'] 2
# ['Anthony', 'Stevens'] 2
# ['Sarah', 'Cruz'] 2
# ['Jeffrey', 'Johnson'] 2
# ['Daniel', 'Rich'] 2
# ['Misty', 'Morrison'] 2
# ['Robert', 'Sanchez'] 2
# ['Kevin', 'Lopez'] 2
# ['Haley', 'Figueroa'] 2
# ['John', 'Jackson'] 2
# ['Kathryn', 'Rodgers'] 2
# ['Kathleen', 'Cervantes'] 2
# ['Kristin', 'Dalton'] 2
# ['Gary', 'Walker'] 2
# ['Stacey', 'Johnson'] 2
# ['Carol', 'Hobbs'] 2
# ['Linda', 'Arellano'] 2
# ['Kayla', 'Serrano'] 2
# ['David', 'Banks'] 2
# ['Barry', 'Steele'] 2
# ['Lori', 'Huang'] 2
# ['Dylan', 'Johnson'] 2
# ['Rodney', 'Jenkins'] 2
# ['Sean', 'Kelly'] 2
# ['Thomas', 'Solis'] 2
# ['Nicole', 'Vazquez'] 2
# ['Jennifer', 'Francis'] 2
# ['Joseph', 'Olson'] 2
# ['Marcus', 'Olson'] 2
# ['John', 'Martin'] 2
# ['Alexander', 'Gonzalez'] 2
# ['Donald', 'Delacruz'] 2
# ['Scott', 'Gibson'] 2
# ['Jamie', 'Hines'] 2
# ['Susan', 'Porter'] 2
# ['Laura', 'Alvarado'] 2
# ['Linda', 'Mccann'] 2
# ['Luke', 'Klein'] 2
# ['Michelle', 'Perkins'] 2
# ['Barbara', 'Francis'] 2
# ['Lydia', 'Norris'] 2
# ['Patricia', 'Salazar'] 2
# ['Cynthia', 'Stanley'] 2
# ['Ian', 'Gardner'] 2
# ['Anthony', 'French'] 2
# ['Amanda', 'Haynes'] 2
# ['Kendra', 'Pope'] 2
# ['Jennifer', 'Collins'] 2
# ['Antonio', 'Leon'] 2
# ['William', 'Roberts'] 2
# ['Richard', 'Peterson'] 2
# ['Margaret', 'Archer'] 2
# ['Philip', 'Hendrix'] 2
# ['Deborah', 'Quinn'] 2
# ['Joshua', 'Calhoun'] 2
# ['Thomas', 'Terry'] 2
# ['James', 'Ray'] 2
# ['William', 'Johnson'] 2
# ['Laura', 'Oneill'] 2
# ['Lisa', 'Delgado'] 2
# ['Victor', 'Vega'] 2
# ['Stacy', 'Cook'] 2
# ['Eric', 'Smith'] 2
# ['Tracy', 'Woods'] 2
# ['Amy', 'Stokes'] 2
# ['Dr.', 'Christina', 'Moore'] 3
# ['Gregory', 'Mitchell'] 2
# ['Jennifer', 'Waters'] 2
# ['Courtney', 'Fuller'] 2
# ['Christopher', 'Green'] 2
# ['Laura', 'Richardson'] 2
# ['Heather', 'Chen'] 2
# ['Joel', 'Hale'] 2
# ['Justin', 'Parks'] 2
# ['Justin', 'Meyer'] 2
# ['Jay', 'Ochoa'] 2
# ['Paul', 'King'] 2
# ['Amanda', 'Chandler'] 2
# ['Angela', 'Peterson', 'MD'] 3
# ['James', 'Williams'] 2
# ['Jeremiah', 'Mcconnell'] 2
# ['Rita', 'Salazar'] 2
# ['Shawn', 'Moore'] 2
# ['Holly', 'Gallagher'] 2
# ['Ashley', 'Espinoza'] 2
# ['Melissa', 'Roach'] 2
# ['Meghan', 'Sanders'] 2
# ['Richard', 'Griffin'] 2
# ['Jonathan', 'Cline'] 2
# ['Mark', 'Yu'] 2
# ['Michael', 'Bishop'] 2
# ['Katherine', 'Anderson'] 2
# ['Hannah', 'White'] 2
# ['James', 'Davis'] 2
# ['Richard', 'Gomez'] 2
# ['Grace', 'Lynch'] 2
# ['Michael', 'Hart'] 2
# ['Cameron', 'Patterson'] 2
# ['Melissa', 'Lewis'] 2
# ['Joanne', 'Davidson'] 2
# ['Kelly', 'Preston'] 2
# ['Yvonne', 'Pruitt'] 2
# ['Peter', 'Johnson'] 2
# ['Lauren', 'Rios'] 2
# ['Timothy', 'Davis'] 2
# ['Jennifer', 'Macias'] 2
# ['Isabel', 'Buchanan'] 2
# ['Scott', 'Lee'] 2
# ['Janice', 'Cook'] 2
# ['Shannon', 'Nguyen'] 2
# ['Juan', 'Vance'] 2
# ['Erik', 'White'] 2
# ['Kimberly', 'Stone'] 2
# ['Jennifer', 'Ferguson', 'MD'] 3
# ['Heather', 'Smith'] 2
# ['Christian', 'Flores'] 2
# ['Tara', 'Smith'] 2
# ['Brent', 'Mejia'] 2
# ['Glenn', 'Stevens'] 2
# ['Mikayla', 'Harvey'] 2
# ['Hannah', 'Moore'] 2
# ['Christina', 'Wagner'] 2
# ['Joshua', 'Huang'] 2
# ['Samantha', 'Moore'] 2
# ['Martin', 'Combs'] 2
# ['Katelyn', 'Bates'] 2
# ['Julian', 'Reyes'] 2
# ['Michael', 'Rios'] 2
# ['Christopher', 'Green'] 2
# ['Brenda', 'Carrillo'] 2
# ['Robert', 'Arias'] 2
# ['Tanya', 'Wolf'] 2
# ['Casey', 'Anderson'] 2
# ['Scott', 'Castillo'] 2
# ['Sierra', 'Gonzalez'] 2
# ['Patricia', 'Taylor'] 2
# ['Kyle', 'Alvarado'] 2
# ['Jeremy', 'Manning'] 2
# ['Benjamin', 'Burns'] 2
# ['Steven', 'Thompson'] 2
# ['Gregory', 'Miranda'] 2
# ['Jessica', 'Castro'] 2
# ['William', 'Franklin'] 2
# ['Barbara', 'Cardenas'] 2
# ['Gregory', 'Graham'] 2
# ['Tammy', 'Mckenzie'] 2
# ['Joshua', 'Glenn'] 2
# ['Amanda', 'Myers'] 2
# ['Jerry', 'Gonzales'] 2
# ['Anthony', 'Wilson', 'DDS'] 3
# ['Kevin', 'Mcbride'] 2
# ['Adam', 'Reed'] 2
# ['Clifford', 'Kirby'] 2
# ['John', 'Boyd'] 2
# ['Dawn', 'Bryant'] 2
# ['Rebecca', 'Washington'] 2
# ['Katelyn', 'Mccormick'] 2
# ['Abigail', 'White'] 2
# ['Timothy', 'Brennan'] 2
# ['Alyssa', 'Williams'] 2
# ['Timothy', 'Graves'] 2
# ['Christopher', 'Jones'] 2
# ['Joel', 'Johnson'] 2
# ['John', 'Hill'] 2
# ['Rebekah', 'Rangel'] 2
# ['Melissa', 'Huang'] 2
# ['Nathan', 'Hall'] 2
# ['Christopher', 'Owen'] 2
# ['Courtney', 'Jimenez'] 2
# ['Benjamin', 'Carter'] 2
# ['Shannon', 'Zimmerman'] 2
# ['Nicole', 'Wolf'] 2
# ['Kevin', 'Henry'] 2
# ['Mark', 'Lane'] 2
# ['Timothy', 'Sims'] 2
# ['Dr.', 'Jessica', 'Lopez'] 3
# ['Jeffrey', 'Robinson'] 2
# ['Tyler', 'Collins'] 2
# ['Alexis', 'Roberts'] 2
# ['Taylor', 'Avery'] 2
# ['Mark', 'Fitzpatrick'] 2
# ['Michael', 'Bailey'] 2
# ['Ashley', 'Guerra'] 2
# ['Dawn', 'Martinez'] 2
# ['Rachel', 'Perez'] 2
# ['Nathan', 'Barajas'] 2
# ['David', 'Miller', 'Jr.'] 3
# ['William', 'Carter'] 2
# ['Matthew', 'Chapman'] 2
# ['William', 'Wells'] 2
# ['William', 'Hartman'] 2
# ['Michael', 'Moore'] 2
# ['Rebecca', 'Castro'] 2
# ['Douglas', 'Baker'] 2
# ['Pamela', 'Bush'] 2
# ['Emily', 'Collins'] 2
# ['John', 'Norton'] 2
# ['Sherry', 'Morales'] 2
# ['Anthony', 'Kirk'] 2
# ['Katelyn', 'Moore'] 2
# ['Rhonda', 'Jackson'] 2
# ['Dennis', 'Holden'] 2
# ['Catherine', 'Meyers'] 2
# ['Robert', 'Lowe'] 2
# ['Rachel', 'Ramirez'] 2
# ['Pamela', 'Walker'] 2
# ['Brian', 'Arroyo'] 2
# ['Natalie', 'Strickland'] 2
# ['Kevin', 'Khan'] 2
# ['Cynthia', 'May'] 2
# ['Patricia', 'Curtis'] 2
# ['Ashley', 'White'] 2
# ['Cindy', 'Williams'] 2
# ['Sara', 'Carpenter'] 2
# ['Jose', 'Murray'] 2
# ['Crystal', 'Munoz'] 2
# ['Dr.', 'John', 'Jones'] 3
# ['Shannon', 'Johnson'] 2
# ['Elizabeth', 'Bennett'] 2
# ['Teresa', 'Davis'] 2
# ['Rachel', 'Wilson'] 2
# ['Ellen', 'Parsons'] 2
# ['Natalie', 'Flores'] 2
# ['Brooke', 'Anthony'] 2
# ['Rachael', 'Hawkins'] 2
# ['Richard', 'Rodriguez'] 2
# ['Natalie', 'Jones'] 2
# ['Justin', 'Raymond'] 2
# ['Laurie', 'Collins'] 2
# ['Joanna', 'Estes'] 2
# ['Diana', 'Mason'] 2
# ['Mary', 'Glover'] 2
# ['David', 'Santiago'] 2
# ['Natalie', 'Riley'] 2
# ['Ms.', 'Samantha', 'Brown'] 3
# ['Denise', 'Wilson'] 2
# ['Keith', 'Marsh'] 2
# ['Katherine', 'Oconnor'] 2
# ['Craig', 'Brown'] 2
# ['Shelby', 'Delgado'] 2
# ['Christopher', 'Herrera'] 2
# ['Anthony', 'Burton'] 2
# ['David', 'Harris'] 2
# ['John', 'Parker'] 2
# ['Christopher', 'Flores'] 2
# ['Cassandra', 'Ellison'] 2
# ['Francisco', 'Petty'] 2
# ['Eugene', 'Hernandez'] 2
# ['Amy', 'Mora'] 2
# ['Veronica', 'Arnold'] 2
# ['Aaron', 'Sparks'] 2
# ['Christine', 'Shannon'] 2
# ['Joseph', 'Atkinson'] 2
# ['Angela', 'Brown'] 2
# ['Rachel', 'Schwartz'] 2
# ['Jack', 'Miranda'] 2
# ['Andrea', 'Lopez'] 2
# ['Sharon', 'Hudson'] 2
# ['Michael', 'Hobbs'] 2
# ['Matthew', 'Williams'] 2
# ['Holly', 'Hall'] 2
# ['James', 'Harris'] 2
# ['Jennifer', 'Carpenter'] 2
# ['Jennifer', 'Lopez'] 2
# ['Michelle', 'Flores'] 2
# ['Jennifer', 'Higgins'] 2
# ['David', 'Allen'] 2
# ['Jeffrey', 'Perez'] 2
# ['Reginald', 'Allen'] 2
# ['Kaitlyn', 'Hansen'] 2
# ['Franklin', 'Reyes'] 2
# ['Gerald', 'Mcmahon'] 2
# ['Alison', 'Crawford'] 2
# ['Michael', 'Stevenson'] 2
# ['Donald', 'Navarro'] 2
# ['Stephen', 'Vasquez'] 2
# ['Tina', 'Morrow'] 2
# ['Stacy', 'Pace'] 2
# ['Heidi', 'Robles'] 2
# ['Adam', 'Small'] 2
# ['David', 'Farmer'] 2
# ['Jeremiah', 'Torres'] 2
# ['April', 'Gutierrez'] 2
# ['Cynthia', 'Hansen', 'DVM'] 3
# ['Rachel', 'Miller'] 2
# ['Sarah', 'Joseph'] 2
# ['Lori', 'Wells'] 2
# ['Veronica', 'Anderson'] 2
# ['Renee', 'Mahoney'] 2
# ['Megan', 'Spence'] 2
# ['Michelle', 'Mills'] 2
# ['Rebecca', 'Montoya', 'MD'] 3
# ['Margaret', 'Koch'] 2
# ['Danny', 'Aguirre'] 2
# ['Cheryl', 'Malone'] 2
# ['Stacy', 'Ramos'] 2
# ['Richard', 'Lozano'] 2
# ['Garrett', 'Davis'] 2
# ['Javier', 'Steele'] 2
# ['Matthew', 'Kerr'] 2
# ['Samuel', 'Davis'] 2
# ['Stephanie', 'Kirby'] 2
# ['Stephanie', 'Burch'] 2
# ['David', 'Nguyen'] 2
# ['Brandy', 'Campbell'] 2
# ['James', 'Noble'] 2
# ['Marie', 'Bowman'] 2
# ['Jennifer', 'Henry'] 2
# ['Steven', 'Lewis'] 2
# ['David', 'Johnson'] 2
# ['Amy', 'Martin'] 2
# ['Michelle', 'Mitchell'] 2
# ['Christopher', 'Brown'] 2
# ['Steven', 'Houston'] 2
# ['Ernest', 'Campbell'] 2
# ['Courtney', 'Carlson'] 2
# ['James', 'Black'] 2
# ['Edward', 'Spence'] 2
# ['Anthony', 'Lee'] 2
# ['Michael', 'Gonzales'] 2
# ['Lori', 'Figueroa'] 2
# ['Andrew', 'Maynard'] 2
# ['Linda', 'Lewis'] 2
# ['Daniel', 'Kelley'] 2
# ['Duane', 'Hoffman'] 2
# ['Jenny', 'Barber'] 2
# ['Jillian', 'Kaiser'] 2
# ['Zoe', 'Castro'] 2
# ['Jamie', 'Alvarado'] 2
# ['Kristina', 'Pham'] 2
# ['Cathy', 'Garrett'] 2
# ['Albert', 'Anderson'] 2
# ['Ronald', 'Zhang'] 2
# ['Stephanie', 'Cole'] 2
# ['Heather', 'Johnson'] 2
# ['Eric', 'Ferguson'] 2
# ['Mark', 'Collins'] 2
# ['Pamela', 'Taylor'] 2
# ['Sarah', 'Green'] 2
# ['Carol', 'Thomas'] 2
# ['Derek', 'Lopez'] 2
# ['Lisa', 'Harrison'] 2
# ['Kevin', 'Mcdonald'] 2
# ['Patrick', 'Herrera'] 2
# ['Laura', 'Hicks'] 2
# ['Joel', 'Walls'] 2
# ['Katherine', 'Peterson'] 2
# ['Christine', 'Allison'] 2
# ['Dr.', 'Jacob', 'Matthews'] 3
# ['Cassandra', 'Lopez'] 2
# ['Jeremy', 'Mcguire'] 2
# ['Eric', 'Reynolds'] 2
# ['Stephen', 'Maddox'] 2
# ['Erik', 'Hansen'] 2
# ['Andrea', 'Ramsey'] 2
# ['Edgar', 'Rogers'] 2
# ['Ronald', 'Evans'] 2
# ['Susan', 'Roberts'] 2
# ['Janice', 'Shah'] 2
# ['Jon', 'Blake'] 2
# ['Briana', 'Castillo'] 2
# ['Ariana', 'Williamson'] 2
# ['Latasha', 'Wallace'] 2
# ['Sarah', 'Bailey'] 2
# ['Philip', 'Nguyen'] 2
# ['Jordan', 'Miller'] 2
# ['Michael', 'Nunez'] 2
# ['Larry', 'Wilson'] 2
# ['Eric', 'Bush'] 2
# ['Julie', 'Cox'] 2
# ['Savannah', 'Juarez'] 2
# ['Brittney', 'Johnston'] 2
# ['Alan', 'Mckinney'] 2
# ['Deborah', 'Bauer'] 2
# ['Dr.', 'Jacob', 'Bell'] 3
# ['Donna', 'Carter'] 2
# ['Luke', 'Cook'] 2
# ['Marcus', 'Thomas'] 2
# ['Christopher', 'George'] 2
# ['Chad', 'Hill'] 2
# ['Brian', 'Johnson'] 2
# ['Kristin', 'Velasquez'] 2
# ['Alexis', 'Moss'] 2
# ['Samantha', 'Wilson'] 2
# ['Alexander', 'Collins'] 2
# ['Crystal', 'Pena'] 2
# ['Adam', 'Tucker'] 2
# ['Tiffany', 'Mitchell'] 2
# ['Donald', 'Anderson'] 2
# ['Mr.', 'Bruce', 'Thomas'] 3
# ['Samantha', 'Lowe'] 2
# ['Karen', 'Zimmerman'] 2
# ['Jeremy', 'Dean'] 2
# ['Joseph', 'Dominguez'] 2
# ['Ronald', 'Carpenter'] 2
# ['Nicholas', 'Blake'] 2
# ['Dustin', 'Atkinson'] 2
# ['Ralph', 'Peters'] 2
# ['Tyler', 'Scott'] 2
# ['Christopher', 'Weaver'] 2
# ['Carla', 'Jefferson'] 2
# ['Sharon', 'Davies'] 2
# ['Rodney', 'Stephens'] 2
# ['Courtney', 'Rodriguez'] 2
# ['Dawn', 'Martinez'] 2
# ['Alicia', 'Hernandez'] 2
# ['Matthew', 'Weaver'] 2
# ['Alexa', 'Harper'] 2
# ['Danielle', 'Matthews'] 2
# ['Taylor', 'Orr'] 2
# ['Courtney', 'Davis'] 2
# ['Anita', 'Cross'] 2
# ['Bryce', 'Mercer'] 2
# ['Andrea', 'Haley'] 2
# ['Kristina', 'Armstrong'] 2
# ['Carl', 'Peters'] 2
# ['Kathryn', 'Brown'] 2
# ['Tina', 'Jones'] 2
# ['Susan', 'Evans'] 2
# ['William', 'Reyes'] 2
# ['William', 'Howard'] 2
# ['Robert', 'Martin', 'MD'] 3
# ['Kathryn', 'Boyd'] 2
# ['Michelle', 'Hall'] 2
# ['Bradley', 'Miller'] 2
# ['Donald', 'Cole'] 2
# ['Anthony', 'Allen'] 2
# ['Brett', 'May'] 2
# ['Ryan', 'Sanchez'] 2
# ['Angel', 'Werner'] 2
# ['Michael', 'Small'] 2
# ['Megan', 'Conner'] 2
# ['Daniel', 'Russell'] 2
# ['Jamie', 'Watkins'] 2
# ['Amber', 'Wade'] 2
# ['Laura', 'Ford'] 2
# ['James', 'Wilson'] 2
# ['Derrick', 'Wright'] 2
# ['Danielle', 'Patel'] 2
# ['Mrs.', 'Marcia', 'Jones', 'PhD'] 4
# ['Sharon', 'Blackburn'] 2
# ['April', 'Morgan'] 2
# ['Adrian', 'Greene'] 2
# ['Reginald', 'Garcia', 'IV'] 3
# ['Robert', 'Spencer'] 2
# ['Michael', 'Abbott'] 2
# ['Scott', 'Stewart'] 2
# ['James', 'Watts'] 2
# ['Jill', 'Lewis'] 2
# ['Joshua', 'Perry'] 2
# ['Stacey', 'Walker'] 2
# ['Nancy', 'Gray'] 2
# ['Alfred', 'Barnes'] 2
# ['Tina', 'Morales'] 2
# ['Laura', 'Bennett'] 2
# ['John', 'Day'] 2
# ['Christina', 'Jones'] 2
# ['Matthew', 'Williams'] 2
# ['George', 'Lewis'] 2
# ['Bridget', 'Holmes'] 2
# ['Mary', 'Wong'] 2
# ['David', 'Walker'] 2
# ['Stephanie', 'Miller'] 2
# ['Jeremy', 'Kirk'] 2
# ['Bobby', 'Williams'] 2
# ['Douglas', 'Warren'] 2
# ['Kevin', 'Noble'] 2
# ['Daryl', 'Hill'] 2
# ['Sabrina', 'Carey'] 2
# ['Carl', 'Dillon'] 2
# ['Daniel', 'Johnson'] 2
# ['Brittany', 'Simmons'] 2
# ['Stephanie', 'Harris'] 2
# ['Angela', 'Carroll'] 2
# ['Diana', 'Brown'] 2
# ['Lonnie', 'Burns'] 2
# ['Matthew', 'Vasquez'] 2
# ['Robert', 'Gonzalez'] 2
# ['Lauren', 'Hutchinson'] 2
# ['James', 'Price'] 2
# ['Zachary', 'Holmes'] 2
# ['Jill', 'Whitehead'] 2
# ['Chad', 'Hoffman'] 2
# ['Sandra', 'Barrett'] 2
# ['Joseph', 'Mendoza'] 2
# ['Christopher', 'Ruiz'] 2
# ['Jessica', 'Jones'] 2
# ['Kevin', 'Bauer'] 2
# ['Micheal', 'Williams'] 2
# ['Patricia', 'Smith', 'MD'] 3
# ['Robert', 'Villa'] 2
# ['Jose', 'Lucas'] 2
# ['Kelly', 'Wolf'] 2
# ['Sara', 'Sherman'] 2
# ['Megan', 'Stevenson'] 2
# ['Richard', 'Elliott'] 2
# ['Paul', 'Reed'] 2
# ['Michael', 'Wilson'] 2
# ['James', 'Day'] 2
# ['Breanna', 'Gregory'] 2
# ['Jennifer', 'Benjamin'] 2
# ['Pam', 'Alvarez'] 2
# ['Mariah', 'Luna'] 2
# ['Amy', 'Dyer', 'DDS'] 3
# ['Cathy', 'Allen'] 2
# ['Samuel', 'Anderson'] 2
# ['Raymond', 'Alexander'] 2
# ['Nicole', 'Salinas'] 2
# ['James', 'Davidson'] 2
# ['Susan', 'Schneider'] 2
# ['Michael', 'Snow'] 2
# ['Tammy', 'Fisher'] 2
# ['Amanda', 'Henry'] 2
# ['Nicholas', 'Jenkins'] 2
# ['Debbie', 'Gill'] 2
# ['Susan', 'Fernandez'] 2
# ['Brian', 'Hall', 'DDS'] 3
# ['Shannon', 'Vance'] 2
# ['Phillip', 'Joseph'] 2
# ['Thomas', 'Fisher'] 2
# ['Ashley', 'Johnson'] 2
# ['Patrick', 'Santos'] 2
# ['Anthony', 'Villarreal'] 2
# ['Dennis', 'Brown'] 2
# ['Spencer', 'Matthews'] 2
# ['Kimberly', 'Brown'] 2
# ['Jessica', 'Joseph'] 2
# ['Erika', 'Page'] 2
# ['Joseph', 'Mccall'] 2
# ['Cole', 'Berger'] 2
# ['Laura', 'Cochran'] 2
# ['Jay', 'Wright'] 2
# ['Kevin', 'Schneider'] 2
# ['Lindsay', 'Clark'] 2
# ['Brian', 'Richards'] 2
# ['Laurie', 'Sheppard'] 2
# ['Sarah', 'Garcia'] 2
# ['Kim', 'Henry'] 2
# ['Ricky', 'Carrillo'] 2
# ['Kelly', 'Ramirez'] 2
# ['Mary', 'Jones'] 2
# ['Brittany', 'Morris'] 2
# ['Douglas', 'Levy', 'DDS'] 3
# ['Joseph', 'Reyes'] 2
# ['Michael', 'Garcia'] 2
# ['Amanda', 'Guzman'] 2
# ['Tracey', 'Johnson'] 2
# ['Diana', 'Nelson'] 2
# ['Willie', 'Werner'] 2
# ['Danielle', 'Robles'] 2
# ['Andrea', 'Gonzalez'] 2
# ['Kenneth', 'Ruiz'] 2
# ['Mr.', 'Eric', 'Ibarra'] 3
# ['Nichole', 'Simmons'] 2
# ['Richard', 'Rodriguez'] 2
# ['Jesus', 'Molina'] 2
# ['Brenda', 'Gibson'] 2
# ['Diana', 'Vaughan'] 2
# ['Christine', 'Tanner'] 2
# ['Patrick', 'Gonzales'] 2
# ['George', 'Melendez'] 2
# ['Marcus', 'Torres'] 2
# ['Andrew', 'Clark'] 2
# ['Benjamin', 'Ramirez', 'MD'] 3
# ['Todd', 'Ramirez'] 2
# ['Sharon', 'Swanson'] 2
# ['Brittany', 'Stevens'] 2
# ['Stephanie', 'Mendoza'] 2
# ['Ariana', 'Garcia'] 2
# ['Steven', 'Jenkins'] 2
# ['Jennifer', 'Reyes'] 2
# ['Alexandra', 'Oliver'] 2
# ['Anna', 'Schneider'] 2
# ['Marcus', 'Stewart'] 2
# ['Kenneth', 'Adams'] 2
# ['Tanner', 'Welch'] 2
# ['Martha', 'Wilson'] 2
# ['Lindsey', 'Anderson'] 2
# ['Julia', 'Camacho'] 2
# ['Raymond', 'Freeman', 'DDS'] 3
# ['Rachel', 'Jones'] 2
# ['Stephanie', 'Reese'] 2
# ['Sharon', 'Tapia'] 2
# ['Timothy', 'Hall'] 2
# ['Stacy', 'Brown'] 2
# ['Nicole', 'White'] 2
# ['James', 'Diaz'] 2
# ['James', 'Cooke'] 2
# ['Philip', 'Walsh'] 2
# ['Joshua', 'Green'] 2
# ['Teresa', 'Perez'] 2
# ['Shannon', 'Jackson'] 2
# ['Rodney', 'Spencer'] 2
# ['Bradley', 'Williams'] 2
# ['Emily', 'Walker'] 2
# ['Anthony', 'Beck'] 2
# ['Brooke', 'Stephens'] 2
# ['Dorothy', 'Alvarez'] 2
# ['Ryan', 'Lane'] 2
# ['Samantha', 'Walker'] 2
# ['Frank', 'Hall'] 2
# ['Rachel', 'Smith'] 2
# ['Kimberly', 'Sanchez'] 2
# ['Kristy', 'Evans'] 2
# ['Elizabeth', 'Johnson'] 2
# ['Javier', 'Juarez'] 2
# ['Jason', 'Murphy'] 2
# ['Brian', 'White'] 2
# ['Christopher', 'Thompson'] 2
# ['Alicia', 'Martinez'] 2
# ['Anita', 'Myers'] 2
# ['Shannon', 'Horne'] 2
# ['Lucas', 'Brown'] 2
# ['Gina', 'Kelly'] 2
# ['Eric', 'Robbins'] 2
# ['Tommy', 'Mitchell'] 2
# ['Sarah', 'Johnson'] 2
# ['Richard', 'Garcia'] 2
# ['Heather', 'Bryant'] 2
# ['Julia', 'Duffy'] 2
# ['Michelle', 'Morales'] 2
# ['Tracey', 'Santana'] 2
# ['Bradley', 'Harmon'] 2
# ['Cheryl', 'Hill'] 2
# ['Rebecca', 'Coleman'] 2
# ['Autumn', 'Price'] 2
# ['Chris', 'Hudson'] 2
# ['Mary', 'Roberts'] 2
# ['Christopher', 'Martinez'] 2
# ['Amy', 'Underwood'] 2
# ['Cheryl', 'Avery'] 2
# ['James', 'Fisher'] 2
# ['Wendy', 'Chase'] 2
# ['Carla', 'Reeves', 'MD'] 3
# ['Darrell', 'Rangel'] 2
# ['Allison', 'Sanchez'] 2
# ['John', 'Howard'] 2
# ['Tammy', 'Lewis'] 2
# ['Stephanie', 'Hart'] 2
# ['Douglas', 'Tran'] 2
# ['Andrew', 'Bailey'] 2
# ['Justin', 'Smith'] 2
# ['Gavin', 'Kennedy'] 2
# ['Daniel', 'Mathews'] 2
# ['Bryan', 'Logan'] 2
# ['Misty', 'Gregory'] 2
# ['Robert', 'Garcia'] 2
# ['Victor', 'Robinson'] 2
# ['William', 'Terry'] 2
# ['Christopher', 'Lowery'] 2
# ['Joseph', 'Marshall'] 2
# ['Christopher', 'Lee'] 2
# ['Elizabeth', 'Swanson'] 2
# ['Ashley', 'Cantu'] 2
# ['Daniel', 'Jenkins'] 2
# ['Dr.', 'Donald', 'Williams'] 3
# ['Jessica', 'Perez'] 2
# ['Sonia', 'Phillips'] 2
# ['Christopher', 'Graves'] 2
# ['Benjamin', 'Delacruz'] 2
# ['Victor', 'Moss'] 2
# ['Randy', 'Bentley'] 2
# ['Samuel', 'Thompson'] 2
# ['Tonya', 'Taylor'] 2
# ['Vincent', 'Morton'] 2
# ['Sherry', 'Barry'] 2
# ['Jack', 'Walsh'] 2
# ['Gregory', 'Carter'] 2
# ['Amanda', 'Rice'] 2
# ['Alex', 'Duffy'] 2
# ['Richard', 'Butler'] 2
# ['Christian', 'Gray'] 2
# ['Elizabeth', 'Cain'] 2
# ['Michael', 'Clark'] 2
# ['Paul', 'Webster'] 2
# ['Michelle', 'Braun'] 2
# ['Jay', 'Ward'] 2
# ['Rachel', 'White'] 2
# ['Dean', 'Turner'] 2
# ['Kevin', 'Obrien'] 2
# ['Andrea', 'Davis'] 2
# ['Diana', 'Hammond'] 2
# ['Jessica', 'Poole'] 2
# ['Juan', 'Smith'] 2
# ['Mr.', 'John', 'Carter'] 3
# ['Crystal', 'Lewis'] 2
# ['Julia', 'Jackson'] 2
# ['Kristen', 'Marquez'] 2
# ['David', 'Greene'] 2
# ['Martin', 'Stephenson'] 2
# ['Penny', 'Page'] 2
# ['William', 'Jackson', 'DVM'] 3
# ['Jasmine', 'Hunter'] 2
# ['Anna', 'West'] 2
# ['Charles', 'Ortiz'] 2
# ['Lori', 'Spencer'] 2
# ['Robert', 'Hendrix'] 2
# ['Christie', 'Gill'] 2
# ['Kristopher', 'Raymond'] 2
# ['Brian', 'Whitaker'] 2
# ['Donna', 'Hendrix'] 2
# ['Jose', 'Swanson'] 2
# ['Diane', 'Hodge'] 2
# ['Kimberly', 'Griffin'] 2
# ['Lisa', 'Cervantes'] 2
# ['John', 'Dawson'] 2
# ['Michele', 'Martin'] 2
# ['Stephanie', 'Reilly'] 2
# ['Michele', 'Adams'] 2
# ['Angela', 'Miles'] 2
# ['Henry', 'Roman'] 2
# ['Carrie', 'Gallagher'] 2
# ['Jason', 'Mays'] 2
# ['Marissa', 'Livingston'] 2
# ['Joshua', 'Johnson'] 2
# ['Kristina', 'Lane'] 2
# ['William', 'Hernandez'] 2
# ['Megan', 'Stevens'] 2
# ['Kylie', 'Torres'] 2
# ['Terri', 'Lee'] 2
# ['Mr.', 'Mitchell', 'Cooper'] 3
# ['Ann', 'Eaton'] 2
# ['Damon', 'Pearson'] 2
# ['Molly', 'Davis'] 2
# ['Matthew', 'Donaldson'] 2
# ['Rhonda', 'Carter'] 2
# ['James', 'Todd'] 2
# ['Jeremiah', 'James'] 2
# ['Bradley', 'Craig'] 2
# ['Dennis', 'Brown'] 2
# ['Timothy', 'Reed'] 2
# ['David', 'Morgan'] 2
# ['Sarah', 'Parrish'] 2
# ['Sarah', 'Page'] 2
# ['Kathleen', 'Hudson'] 2
# ['Jeffrey', 'Thomas'] 2
# ['Jonathan', 'Moses'] 2
# ['Lisa', 'Williams'] 2
# ['Tony', 'Bass'] 2
# ['Neil', 'Brown'] 2
# ['Luis', 'Escobar'] 2
# ['Zachary', 'Rivera'] 2
# ['Cheryl', 'Sutton'] 2
# ['Shawn', 'French'] 2
# ['Stephen', 'Molina'] 2
# ['Ashley', 'Mcmahon'] 2
# ['Tammy', 'Dean'] 2
# ['Wayne', 'Butler'] 2
# ['Nicole', 'Smith'] 2
# ['April', 'Tyler'] 2
# ['Christopher', 'Johnson'] 2
# ['Brian', 'Stafford'] 2
# ['Norma', 'Conley'] 2
# ['Natasha', 'Velazquez'] 2
# ['Thomas', 'Hampton'] 2
# ['Billy', 'Oconnell'] 2
# ['Katherine', 'Munoz'] 2
# ['Kevin', 'Brown', 'IV'] 3
# ['Karen', 'White'] 2
# ['David', 'Gordon'] 2
# ['Marvin', 'Jackson'] 2
# ['Emily', 'King'] 2
# ['Julia', 'Finley'] 2
# ['David', 'Powell'] 2
# ['Jeffrey', 'Davis'] 2
# ['Chloe', 'Williams'] 2
# ['Jacqueline', 'Wells'] 2
# ['Ethan', 'Clark'] 2
# ['Mitchell', 'Dixon'] 2
# ['Elizabeth', 'Rivas'] 2
# ['Sandra', 'Wong'] 2
# ['Brooke', 'Sellers'] 2
# ['Alexis', 'Bright'] 2
# ['Jacqueline', 'Hooper'] 2
# ['Mrs.', 'Kathleen', 'Reed'] 3
# ['Shelia', 'Thompson'] 2
# ['David', 'Jones'] 2
# ['Elijah', 'Wood'] 2
# ['Alyssa', 'Donaldson'] 2
# ['Andrew', 'Howard'] 2
# ['Tiffany', 'Reynolds'] 2
# ['Jamie', 'Mccoy'] 2
# ['Erin', 'Rodriguez'] 2
# ['Anne', 'Roberts'] 2
# ['Benjamin', 'Hammond'] 2
# ['Roy', 'Mcdowell'] 2
# ['Erica', 'Huber'] 2
# ['Michael', 'Singleton'] 2
# ['Joshua', 'Jackson'] 2
# ['Diana', 'Holmes'] 2
# ['Michael', 'Whitney'] 2
# ['Laura', 'Clay'] 2
# ['Cindy', 'Sparks'] 2
# ['Erin', 'Harvey'] 2
# ['Wendy', 'Baker'] 2
# ['Gary', 'Duncan'] 2
# ['Mark', 'White'] 2
# ['Joshua', 'Wilson'] 2
# ['Tyler', 'Griffin'] 2
# ['Kevin', 'Harris'] 2
# ['Michael', 'Kim'] 2
# ['Veronica', 'Booth'] 2
# ['Kimberly', 'Smith'] 2
# ['Patricia', 'Santana'] 2
# ['Dawn', 'Mcgee'] 2
# ['Dylan', 'Villegas'] 2
# ['William', 'Evans'] 2
# ['Gregory', 'Griffin'] 2
# ['Matthew', 'Keller'] 2
# ['Larry', 'Hernandez'] 2
# ['Bryan', 'Grimes'] 2
# ['Daniel', 'Alvarez'] 2
# ['Eric', 'Wright'] 2
# ['Justin', 'Smith'] 2
# ['Derek', 'Long'] 2
# ['Leslie', 'Green'] 2
# ['Brooke', 'Mcdonald'] 2
# ['Fernando', 'Brown'] 2
# ['Brian', 'Russell'] 2
# ['Jason', 'Decker'] 2
# ['Jennifer', 'Cruz'] 2
# ['Eric', 'Moore'] 2
# ['Gina', 'Edwards'] 2
# ['Crystal', 'Wright'] 2
# ['Austin', 'Evans'] 2
# ['Kenneth', 'Graham'] 2
# ['James', 'Watkins'] 2
# ['Christopher', 'Stevens'] 2
# ['Jason', 'Lopez'] 2
# ['Nancy', 'Harrison'] 2
# ['Maria', 'Massey'] 2
# ['Beverly', 'Burns'] 2
# ['Jennifer', 'Buckley'] 2
# ['Christopher', 'Vaughn'] 2
# ['Richard', 'Baker'] 2
# ['Eric', 'Johnson'] 2
# ['Jennifer', 'Anderson'] 2
# ['Valerie', 'Turner'] 2
# ['Paul', 'Randolph'] 2
# ['Brian', 'Taylor'] 2
# ['Katherine', 'Neal'] 2
# ['Albert', 'Reid'] 2
# ['Charles', 'Newman'] 2
# ['Laura', 'Reynolds'] 2
# ['Jesus', 'Howell'] 2
# ['Wendy', 'Gonzales'] 2
# ['Katie', 'Soto'] 2
# ['Daniel', 'Chase'] 2
# ['Sharon', 'Vega'] 2
# ['Jennifer', 'Medina'] 2
# ['Carol', 'Romero'] 2
# ['Peter', 'Green'] 2
# ['Shane', 'Swanson'] 2
# ['Kristin', 'Howe'] 2
# ['Cameron', 'Ramos'] 2
# ['Jennifer', 'Walker'] 2
# ['Joseph', 'Williams'] 2
# ['David', 'Sanchez'] 2
# ['Donna', 'Lang'] 2
# ['James', 'Gordon'] 2
# ['Nancy', 'Smith'] 2
# ['Matthew', 'Solis'] 2
# ['Jeffery', 'Yang'] 2
# ['Justin', 'Chen'] 2
# ['Michael', 'Clay'] 2
# ['Jeffery', 'Hill'] 2
# ['Kara', 'Flores'] 2
# ['Sean', 'Rhodes'] 2
# ['Henry', 'Smith'] 2
# ['Darius', 'Harris'] 2
# ['Amanda', 'Wheeler'] 2
# ['Alison', 'Robinson'] 2
# ['Tammie', 'Rose'] 2
# ['Donald', 'Williams'] 2
# ['Jacqueline', 'Hammond'] 2
# ['Cheryl', 'Brown'] 2
# ['Crystal', 'Bright'] 2
# ['Tiffany', 'Peterson'] 2
# ['Natalie', 'Lee'] 2
# ['Bianca', 'Holland'] 2
# ['Amanda', 'Snow'] 2
# ['Hannah', 'Lynch'] 2
# ['Leslie', 'Guzman'] 2
# ['Cody', 'Mcdonald'] 2
# ['Mitchell', 'Holmes'] 2
# ['Donna', 'Robinson', 'MD'] 3
# ['Deanna', 'Garcia'] 2
# ['Evelyn', 'Boyd'] 2
# ['Joyce', 'Henderson'] 2
# ['Cameron', 'Mcintosh'] 2
# ['Stephanie', 'Lang'] 2
# ['Gary', 'Harper'] 2
# ['Mrs.', 'Dawn', 'Olson', 'DDS'] 4
# ['Mr.', 'Dustin', 'Glover'] 3
# ['Jennifer', 'Hogan'] 2
# ['Kevin', 'Miller'] 2
# ['Nathan', 'Ayers'] 2
# ['Amanda', 'Oneill'] 2
# ['Amanda', 'Davis'] 2
# ['Patricia', 'Calderon'] 2
# ['Jill', 'Wilson'] 2
# ['Richard', 'Swanson'] 2
# ['Traci', 'Holt'] 2
# ['Kelly', 'Smith'] 2
# ['Judith', 'Nelson'] 2
# ['Robert', 'Smith'] 2
# ['Alexis', 'French', 'MD'] 3
# ['Samantha', 'Parker'] 2
# ['Danny', 'Davis'] 2
# ...
# ['Sarah', 'Scott'] 2
# ['Heather', 'Turner'] 2
# ['Roy', 'Page'] 2
# ['Courtney', 'Boyer'] 2
# ['Sarah', 'Camacho'] 2
# ['Ellen', 'Mcgee', 'MD'] 3
# ['Maurice', 'Lee'] 2
# ['Glenn', 'Wood'] 2
# ['Donald', 'Becker'] 2
# ['Michelle', 'Roach'] 2
# ['Dawn', 'Hill'] 2
# ['Ashley', 'Stewart'] 2
# ['Rebecca', 'Ellis'] 2
# ['Leroy', 'Mayo'] 2
# ['Cynthia', 'Franklin'] 2
# ['Max', 'Gregory'] 2
# ['Lance', 'Moss'] 2
# ['Franklin', 'Schwartz'] 2
# ['Carmen', 'Johnson'] 2
# ['Angela', 'Wolf'] 2
# ['Monica', 'Brown'] 2
# ['Juan', 'Griffith'] 2
# ['Javier', 'Francis'] 2
# ['Jeffrey', 'Rubio'] 2
# ['Samantha', 'Kim'] 2
# ['Drew', 'Anderson'] 2
# ['Ryan', 'Simpson'] 2
# ['Raymond', 'Torres'] 2
# ['Alexis', 'Dominguez'] 2
# ['Jerry', 'Fuentes'] 2
# ['Debra', 'Johnson'] 2
# ['Jennifer', 'Anderson'] 2
# ['Eric', 'Giles'] 2
# ['Colleen', 'Johnson'] 2
# ['Allison', 'Washington'] 2
# ['Felicia', 'Gamble'] 2
# ['Stephanie', 'Vaughn'] 2
# ['James', 'Warner'] 2
# ['Amanda', 'Gill'] 2
# ['Debra', 'Barrett'] 2
# ['Valerie', 'Stone'] 2
# ['Shawn', 'Harris'] 2
# ['Candace', 'Garcia'] 2
# ['Michael', 'Thomas'] 2
# ['Daniel', 'Gilbert'] 2
# ['Brandy', 'Hoffman'] 2
# ['Bryan', 'Lopez'] 2
# ['Clayton', 'Coleman'] 2
# ['Nicholas', 'Jones'] 2
# ['Joseph', 'Maxwell'] 2
# ['Sierra', 'Smith'] 2
# ['Penny', 'Johnston'] 2
# ['Jessica', 'Reed'] 2
# ['James', 'Mason'] 2
# ['Gregory', 'Lester'] 2
# ['Dana', 'Wood'] 2
# ['Jonathan', 'Gibson'] 2
# ['Fred', 'Turner'] 2
# ['Tyler', 'Harrison'] 2
# ['Kevin', 'Jackson'] 2
# ['Teresa', 'Morgan'] 2
# ['Jonathan', 'Collier'] 2
# ['Ian', 'Thompson'] 2
# ['Alexandra', 'Rodriguez'] 2
# ['Valerie', 'Jacobs'] 2
# ['Jeff', 'Warren'] 2
# ['Emily', 'Andrews', 'MD'] 3
# ['Jessica', 'Gonzalez'] 2
# ['Cassandra', 'Perez'] 2
# ['Ryan', 'Lee'] 2
# ['Sabrina', 'Navarro'] 2
# ['Debbie', 'Campbell'] 2
# ['Janet', 'Martin'] 2
# ['Heather', 'Allen'] 2
# ['Melissa', 'Beck'] 2
# ['Shelby', 'Boyer'] 2
# ['Katrina', 'Dalton'] 2
# ['Samantha', 'Ewing'] 2
# ['Angela', 'Murray'] 2
# ['Lisa', 'Smith'] 2
# ['James', 'Khan'] 2
# ['Diana', 'Martinez'] 2
# ['Richard', 'Williams', 'PhD'] 3
# ['Terri', 'Smith'] 2
# ['Olivia', 'Rogers'] 2
# ['Kelly', 'Smith'] 2
# ['Raymond', 'Reed'] 2
# ['Nicholas', 'Ray'] 2
# ['Karen', 'Willis'] 2
# ['Aaron', 'Kelly'] 2
# ['Jenna', 'Jones'] 2
# ['Linda', 'Kelly'] 2
# ['Danielle', 'Hernandez'] 2
# ['Joshua', 'Phillips'] 2
# ['Sheila', 'Frank'] 2
# ['Gary', 'Martinez'] 2
# ['Andrew', 'Erickson'] 2
# ['Mark', 'Bell'] 2
# ['Cindy', 'Martinez'] 2
# ['Bernard', 'Farrell'] 2
# ['Brian', 'Wilson'] 2
# ['Louis', 'Johnston'] 2
# ['Mr.', 'Michael', 'Baker', 'PhD'] 4
# ['Dr.', 'Robert', 'Taylor'] 3
# ['Timothy', 'Koch'] 2
# ['Angela', 'Fields'] 2
# ['Amy', 'Green'] 2
# ['Erik', 'Martin'] 2
# ['Anthony', 'Curry'] 2
# ['Paul', 'Jones'] 2
# ['Shawn', 'Robinson'] 2
# ['Jimmy', 'Foley'] 2
# ['Jerry', 'Baker'] 2
# ['Karina', 'Allen'] 2
# ['Stephanie', 'Hurst'] 2
# ['Justin', 'Mitchell'] 2
# ['Kimberly', 'Hansen'] 2
# ['Jorge', 'Ramirez'] 2
# ['Joshua', 'Moreno'] 2
# ['Alexis', 'Hubbard'] 2
# ['Paul', 'Larson'] 2
# ['Laura', 'Cobb'] 2
# ['Shirley', 'Wagner'] 2
# ['Christina', 'Valenzuela'] 2
# ['Grace', 'Taylor'] 2
# ['Nancy', 'Wolfe'] 2
# ['Cassandra', 'Schmidt'] 2
# ['James', 'Bowman'] 2
# ['John', 'Hill'] 2
# ['Johnny', 'Russell'] 2
# ['David', 'Estes'] 2
# ['Julia', 'Lewis'] 2
# ['David', 'Burnett'] 2
# ['Kim', 'Phillips'] 2
# ['Cameron', 'Thornton'] 2
# ['Jeffrey', 'Elliott'] 2
# ['Tiffany', 'Huber'] 2
# ['Audrey', 'Berry'] 2
# ['Kevin', 'Stevens'] 2
# ['Matthew', 'Le'] 2
# ['Ronald', 'Guerra'] 2
# ['Jonathan', 'Miller'] 2
# ['Brian', 'Vasquez'] 2
# ['Penny', 'Franco'] 2
# ['Lori', 'Gray'] 2
# ['Jennifer', 'Hawkins'] 2
# ['Patricia', 'Wilson'] 2
# ['April', 'Newman'] 2
# ['Ryan', 'Taylor'] 2
# ['Joshua', 'Patterson'] 2
# ['Tommy', 'Michael'] 2
# ['Christopher', 'Sharp'] 2
# ['Christina', 'Whitney'] 2
# ['Stacey', 'Walker'] 2
# ['Bobby', 'Fox'] 2
# ['Donald', 'Flynn'] 2
# ['Michael', 'Chan'] 2
# ['Erin', 'Porter'] 2
# ['Michael', 'Woodard'] 2
# ['Kathleen', 'Tapia'] 2
# ['Kevin', 'Cox'] 2
# ['Michelle', 'Smith'] 2
# ['Michael', 'Brady'] 2
# ['Emily', 'Ford'] 2
# ['Lisa', 'Cain'] 2
# ['Carol', 'Mason'] 2
# ['Melissa', 'Graham'] 2
# ['Vanessa', 'Haley'] 2
# ['Jessica', 'Becker'] 2
# ['Cody', 'Reilly'] 2
# ['Tracy', 'Walker'] 2
# ['Jamie', 'Hoover'] 2
# ['Shelia', 'Boyd'] 2
# ['Jennifer', 'Alvarez'] 2
# ['Brittany', 'Mendez'] 2
# ['Amber', 'Gardner'] 2
# ['Stephanie', 'Trevino'] 2
# ['Ricky', 'Brown'] 2
# ['Kenneth', 'Smith'] 2
# ['Joseph', 'Kim'] 2
# ['Scott', 'Ford'] 2
# ['Joshua', 'Cordova'] 2
# ['Jose', 'Larson'] 2
# ['Ronnie', 'Le'] 2
# ['Keith', 'Hicks'] 2
# ['Wayne', 'Brown'] 2
# ['Melvin', 'Leon'] 2
# ['Traci', 'Obrien', 'DDS'] 3
# ['Martin', 'Lee'] 2
# ['Douglas', 'Blake'] 2
# ['Michele', 'Freeman'] 2
# ['Isaac', 'Johnson'] 2
# ['Charles', 'Blevins'] 2
# ['Brandy', 'Suarez'] 2
# ['Kyle', 'Allen'] 2
# ['Katrina', 'Best'] 2
# ['Ruth', 'Cox'] 2
# ['Melissa', 'Stanley'] 2
# ['Katelyn', 'Diaz'] 2
# ['Carol', 'Brown'] 2
# ['Edward', 'Conway'] 2
# ['Joshua', 'Paul'] 2
# ['Amanda', 'Edwards'] 2
# ['John', 'Torres'] 2
# ['Richard', 'Roberts'] 2
# ['Joseph', 'Acevedo'] 2
# ['Joseph', 'Perez'] 2
# ['Desiree', 'Hayden'] 2
# ['April', 'Rogers'] 2
# ['John', 'Snyder'] 2
# ['Robert', 'Harris', 'MD'] 3
# ['Daniel', 'Cole'] 2
# ['Bryan', 'Garcia'] 2
# ['Kathleen', 'Price'] 2
# ['Christopher', 'Sloan'] 2
# ['Christopher', 'Green'] 2
# ['Leslie', 'Carson'] 2
# ['Susan', 'Brown'] 2
# ['Amber', 'Macias'] 2
# ['Emily', 'Skinner'] 2
# ['Juan', 'Cruz'] 2
# ['Kimberly', 'Romero'] 2
# ['Andrew', 'Pena'] 2
# ['Jordan', 'Schwartz'] 2
# ['Nicole', 'Bautista'] 2
# ['Rachel', 'Miller'] 2
# ['Gary', 'Martin'] 2
# ['Dawn', 'Rivera'] 2
# ['Frederick', 'Edwards'] 2
# ['Eric', 'Green'] 2
# ['William', 'Wright'] 2
# ['Jennifer', 'Salinas'] 2
# ['Benjamin', 'Irwin'] 2
# ['Alfred', 'Durham'] 2
# ['Kyle', 'Pearson'] 2
# ['Calvin', 'Burke'] 2
# ['Aaron', 'Mccarthy'] 2
# ['Angela', 'Higgins'] 2
# ['William', 'Peterson'] 2
# ['Randall', 'Martin'] 2
# ['Carol', 'Chambers'] 2
# ['Carla', 'Tucker'] 2
# ['Tonya', 'Hernandez'] 2
# ['Elizabeth', 'Myers'] 2
# ['Robert', 'Norman'] 2
# ['John', 'Wilson'] 2
# ['Stephen', 'Collins'] 2
# ['Jessica', 'Johnson'] 2
# ['Samantha', 'Donaldson'] 2
# ['Zachary', 'Torres'] 2
# ['Joanne', 'Robinson'] 2
# ['Adrian', 'Collins'] 2
# ['Jeremiah', 'Esparza'] 2
# ['Jason', 'Mckinney'] 2
# ['Joy', 'Barnes'] 2
# ['Kathleen', 'Caldwell'] 2
# ['Lisa', 'Cox'] 2
# ['Patricia', 'Griffin'] 2
# ['Lisa', 'Gonzales'] 2
# ['Lisa', 'Dickson'] 2
# ['Tony', 'Casey'] 2
# ['Elizabeth', 'Bailey'] 2
# ['Richard', 'Mathews'] 2
# ['Kelly', 'Morales'] 2
# ['John', 'Davis'] 2
# ['Erika', 'Acevedo'] 2
# ['Mary', 'Brennan'] 2
# ['Julie', 'Smith'] 2
# ['Diane', 'Davis'] 2
# ['Aaron', 'Gallegos'] 2
# ['Thomas', 'Gray'] 2
# ['James', 'Morris'] 2
# ['Joy', 'Buckley'] 2
# ['Troy', 'Anderson'] 2
# ['James', 'Bailey'] 2
# ['Jamie', 'Branch'] 2
# ['Robert', 'Bowers'] 2
# ['Rhonda', 'Harrison'] 2
# ['Michele', 'York'] 2
# ['Joshua', 'Simpson'] 2
# ['Kari', 'Williams'] 2
# ['Jaime', 'James'] 2
# ['Richard', 'Watts'] 2
# ['Paul', 'Cole'] 2
# ['Trevor', 'Wang'] 2
# ['Jacob', 'Williams'] 2
# ['Aaron', 'Gates'] 2
# ['Rodney', 'Lopez'] 2
# ['Jenny', 'Rodriguez'] 2
# ['Elizabeth', 'Vasquez'] 2
# ['Patricia', 'Morton'] 2
# ['Autumn', 'Kidd'] 2
# ['Amanda', 'Mcdonald'] 2
# ['Kelly', 'Rodriguez'] 2
# ['Evelyn', 'Frederick'] 2
# ['Joy', 'Bass'] 2
# ['Nancy', 'Jones'] 2
# ['Chris', 'Baldwin'] 2
# ['Michael', 'Allen'] 2
# ['Wayne', 'Luna'] 2
# ['Mary', 'Smith'] 2
# ['Don', 'Buchanan'] 2
# ['James', 'Massey'] 2
# ['Taylor', 'Jordan'] 2
# ['Jonathan', 'Kim'] 2
# ['Dawn', 'Watson'] 2
# ['Caitlin', 'White'] 2
# ['Michael', 'Davidson'] 2
# ['Matthew', 'Moreno'] 2
# ['Dr.', 'Diana', 'Martin'] 3
# ['Monica', 'Nguyen'] 2
# ['Stephen', 'Palmer'] 2
# ['Wendy', 'Wallace'] 2
# ['Megan', 'Murphy'] 2
# ['Donald', 'Mckinney'] 2
# ['Sonia', 'Johnson'] 2
# ['Logan', 'Ward', 'MD'] 3
# ['Vincent', 'Williams'] 2
# ['Shawn', 'Carter'] 2
# ['Jason', 'Thompson'] 2
# ['Frank', 'Hodges'] 2
# ['Danny', 'Sullivan'] 2
# ['Jerry', 'Bell'] 2
# ['Gregory', 'Sharp'] 2
# ['Eddie', 'Gilbert'] 2
# ['Dean', 'Cooper'] 2
# ['Joshua', 'Sharp'] 2
# ['Candace', 'Vasquez'] 2
# ['Mrs.', 'Janice', 'Dixon'] 3
# ['Laura', 'Pham'] 2
# ['Gregory', 'Bentley'] 2
# ['Lauren', 'Allen'] 2
# ['Danielle', 'Williams'] 2
# ['David', 'Johnson'] 2
# ['Nancy', 'Holt'] 2
# ['Robert', 'Luna'] 2
# ['Denise', 'Mcconnell'] 2
# ['Gabriel', 'Smith', 'III'] 3
# ['Christopher', 'Adams'] 2
# ['Matthew', 'Sanchez'] 2
# ['Linda', 'Duran', 'DVM'] 3
# ['Mary', 'Stewart'] 2
# ['Amber', 'Edwards'] 2
# ['Craig', 'Rodriguez'] 2
# ['Seth', 'Martin'] 2
# ['Jacob', 'Briggs'] 2
# ['Christopher', 'Fuentes'] 2
# ['Jacob', 'Barry'] 2
# ['Amy', 'Miller'] 2
# ['Ronald', 'Mayer', 'PhD'] 3
# ['Sarah', 'Davis'] 2
# ['Lori', 'Brown'] 2
# ['Christopher', 'Washington'] 2
# ['Morgan', 'Duke'] 2
# ['Donald', 'Mendoza'] 2
# ['Richard', 'Gonzalez'] 2
# ['Elizabeth', 'May'] 2
# ['John', 'Leonard'] 2
# ['Ryan', 'Ayers'] 2
# ['Kathleen', 'Guerrero'] 2
# ['Michael', 'Garner'] 2
# ['Linda', 'Stephens'] 2
# ['Mr.', 'David', 'Smith'] 3
# ['Lauren', 'Allen'] 2
# ['Michael', 'Diaz'] 2
# ['Jennifer', 'Petersen'] 2
# ['Kristina', 'Patterson'] 2
# ['Ethan', 'Miller'] 2
# ['Angela', 'Williams'] 2
# ['Jennifer', 'Knight'] 2
# ['Travis', 'Nolan'] 2
# ['Kevin', 'Mayer'] 2
# ['David', 'Frey'] 2
# ['Cynthia', 'Diaz'] 2
# ['Lucas', 'Diaz'] 2
# ['Sara', 'Chan'] 2
# ['Jerry', 'Lawson'] 2
# ['Dylan', 'Webb'] 2
# ['Adam', 'Carroll'] 2
# ['Donna', 'Kelley'] 2
# ['Virginia', 'Copeland'] 2
# ['Jennifer', 'Ramirez'] 2
# ['Wesley', 'Duran'] 2
# ['Haley', 'Thompson'] 2
# ['Tristan', 'Vega'] 2
# ['Jorge', 'Beck'] 2
# ['Brian', 'Pitts', 'Jr.'] 3
# ['Jessica', 'Cook'] 2
# ['Kayla', 'Small'] 2
# ['Elizabeth', 'Dixon'] 2
# ['Rebecca', 'Taylor'] 2
# ['Kenneth', 'Cooke'] 2
# ['Joseph', 'Smith'] 2
# ['Patrick', 'Serrano'] 2
# ['Scott', 'Kelley'] 2
# ['Ms.', 'Stephanie', 'Rose'] 3
# ['Brian', 'Soto'] 2
# ['Kathy', 'Jones'] 2
# ['Rodney', 'Medina'] 2
# ['Karen', 'Humphrey'] 2
# ['Tyler', 'Wilson'] 2
# ['Robert', 'Moore'] 2
# ['Robert', 'Vega'] 2
# ['Alison', 'Ortiz'] 2
# ['Mr.', 'Richard', 'Stephens'] 3
# ['Lonnie', 'Carr'] 2
# ['Sherry', 'Jackson'] 2
# ['Kathryn', 'Roberts'] 2
# ['Cheryl', 'Benson'] 2
# ['Chelsea', 'Joseph'] 2
# ['Jessica', 'Parks'] 2
# ['Annette', 'Campbell'] 2
# ['Emily', 'Lee'] 2
# ['Shaun', 'Cooper'] 2
# ['Jessica', 'Lawson'] 2
# ['Steven', 'Bailey'] 2
# ['Jason', 'Briggs'] 2
# ['Rebecca', 'Jimenez'] 2
# ['Andrea', 'Edwards'] 2
# ['Leah', 'Thompson'] 2
# ['Bobby', 'Gray'] 2
# ['Nicole', 'Lewis'] 2
# ['Alexandria', 'Johnson'] 2
# ['Jose', 'Roy'] 2
# ['Miss', 'Kimberly', 'Joseph'] 3
# ['Andre', 'Sharp'] 2
# ['Amanda', 'Stanley'] 2
# ['Luke', 'White'] 2
# ['David', 'Wilson'] 2
# ['Lisa', 'Wilson'] 2
# ['James', 'Moore'] 2
# ['Olivia', 'Holmes'] 2
# ['Gary', 'Crawford'] 2
# ['Joseph', 'Hunt'] 2
# ['Joshua', 'Smith'] 2
# ['Johnny', 'Schroeder'] 2
# ['Brittany', 'Jennings'] 2
# ['Ryan', 'Molina'] 2
# ['Caitlin', 'Lee'] 2
# ['Karen', 'Saunders'] 2
# ['Robert', 'Brooks'] 2
# ['Wendy', 'Houston'] 2
# ['Christopher', 'Green'] 2
# ['Abigail', 'Haynes'] 2
# ['Amy', 'Lewis'] 2
# ['Thomas', 'Melton'] 2
# ['Michelle', 'Cardenas'] 2
# ['Perry', 'Hayes'] 2
# ['Christopher', 'Stanley'] 2
# ['Taylor', 'Young'] 2
# ['Joy', 'Fuentes'] 2
# ['Theresa', 'Rice'] 2
# ['Bruce', 'Thompson', 'II'] 3
# ['Timothy', 'Smith'] 2
# ['Brian', 'Gibson'] 2
# ['Breanna', 'Sanders'] 2
# ['Terry', 'Boyd'] 2
# ['Connie', 'White'] 2
# ['Connie', 'Campos'] 2
# ['Cameron', 'Parker'] 2
# ['Regina', 'Olson'] 2
# ['Vincent', 'Baldwin'] 2
# ['Tony', 'Adams', 'DDS'] 3
# ['Angela', 'Hicks'] 2
# ['Mitchell', 'Hansen'] 2
# ['Kimberly', 'Brennan'] 2
# ['Angela', 'Holmes'] 2
# ['April', 'Garza'] 2
# ['Aaron', 'Brandt'] 2
# ['Christopher', 'Braun'] 2
# ['Casey', 'Collier'] 2
# ['Casey', 'Rodriguez'] 2
# ['Kimberly', 'Lewis'] 2
# ['Austin', 'Brooks'] 2
# ['Amber', 'Baxter'] 2
# ['Phillip', 'King'] 2
# ['Karen', 'Pugh'] 2
# ['Michael', 'Jenkins'] 2
# ['Patricia', 'Patel'] 2
# ['Randy', 'Walsh'] 2
# ['Douglas', 'Frazier'] 2
# ['Jennifer', 'Riley'] 2
# ['Adam', 'Ferrell'] 2
# ['Rachel', 'Frederick'] 2
# ['Charlotte', 'Hubbard'] 2
# ['Benjamin', 'Mcpherson'] 2
# ['Todd', 'Morris'] 2
# ['Dean', 'Gray'] 2
# ['Bradley', 'Johnson'] 2
# ['Cheyenne', 'Bradley'] 2
# ['Jesse', 'Martinez'] 2
# ['Sheila', 'Campos'] 2
# ['Stephanie', 'Ramirez'] 2
# ['Elizabeth', 'Serrano'] 2
# ['Vanessa', 'Byrd'] 2
# ['Heather', 'Simpson'] 2
# ['Mike', 'Robinson'] 2
# ['Joy', 'Jennings'] 2
# ['Stephanie', 'Brewer'] 2
# ['Dr.', 'Annette', 'Collins', 'DDS'] 4
# ['Suzanne', 'Newman'] 2
# ['Julia', 'Cross'] 2
# ['Jennifer', 'George'] 2
# ['John', 'Walker'] 2
# ['Ann', 'Ramsey'] 2
# ['Geoffrey', 'Johnson'] 2
# ['Christopher', 'Anthony'] 2
# ['Derek', 'Tyler'] 2
# ['Thomas', 'Reed'] 2
# ['Jessica', 'Martin'] 2
# ['Rachel', 'Knight'] 2
# ['Courtney', 'Gonzalez'] 2
# ['Susan', 'Payne'] 2
# ['April', 'Sullivan'] 2
# ['Jessica', 'Mccann'] 2
# ['Charles', 'Walker'] 2
# ['Tammy', 'Burns'] 2
# ['Ricky', 'Harrison'] 2
# ['Jamie', 'Montgomery'] 2
# ['Shannon', 'Phillips'] 2
# ['Todd', 'Barber'] 2
# ['Desiree', 'King'] 2
# ['Melissa', 'Roberts'] 2
# ['Earl', 'Martinez'] 2
# ['Jose', 'Willis'] 2
# ['Andrew', 'Shea'] 2
# ['Catherine', 'Price'] 2
# ['Matthew', 'Fowler'] 2
# ['Keith', 'Preston'] 2
# ['Mark', 'Wilson'] 2
# ['Jessica', 'Herrera'] 2
# ['Blake', 'Salinas'] 2
# ['Brittany', 'Gutierrez'] 2
# ['Tami', 'Wagner'] 2
# ['Steven', 'James'] 2
# ['Ian', 'Alvarez'] 2
# ['Carlos', 'Brown'] 2
# ['Mary', 'Murray'] 2
# ['Karen', 'Mack'] 2
# ['Curtis', 'Berry'] 2
# ['Jennifer', 'Harvey'] 2
# ['Angelica', 'Phillips'] 2
# ['Amy', 'Miller'] 2
# ['Bryan', 'Padilla'] 2
# ['Lee', 'Alexander'] 2
# ['Dylan', 'Chapman'] 2
# ['Robert', 'Goodwin'] 2
# ['John', 'Vasquez'] 2
# ['George', 'Bowers'] 2
# ['Shannon', 'Larsen'] 2
# ['Cynthia', 'Turner'] 2
# ['Mr.', 'Chad', 'Hendricks'] 3
# ['Trevor', 'Sanders'] 2
# ['Yolanda', 'Velasquez'] 2
# ['Taylor', 'King'] 2
# ['Kenneth', 'Murray'] 2
# ['Deborah', 'Weber'] 2
# ['Cindy', 'Ward'] 2
# ['Andrew', 'Melton'] 2
# ['Jodi', 'Mcpherson'] 2
# ['Samantha', 'Johnson'] 2
# ['Timothy', 'Trevino'] 2
# ['James', 'Kelly'] 2
# ['Marvin', 'Nichols'] 2
# ['Brenda', 'Caldwell'] 2
# ['Dustin', 'Wiggins'] 2
# ['Rebecca', 'Morton'] 2
# ['Carla', 'Brown'] 2
# ['Darlene', 'Williams'] 2
# ['Karen', 'Turner'] 2
# ['April', 'Mccoy'] 2
# ['Tyler', 'Lee'] 2
# ['Laura', 'Moore'] 2
# ['Charles', 'Collins'] 2
# ['Thomas', 'Beard'] 2
# ['Stephen', 'Horton'] 2
# ['Jonathan', 'Watts'] 2
# ['Keith', 'Hayes'] 2
# ['Theresa', 'Blair'] 2
# ['David', 'Martinez'] 2
# ['John', 'Cortez'] 2
# ['Shelley', 'Bolton'] 2
# ['Tiffany', 'Harris'] 2
# ['Brenda', 'West'] 2
# ['Lynn', 'Lyons'] 2
# ['Joshua', 'Hughes'] 2
# ['Richard', 'Jordan'] 2
# ['Dennis', 'Watson'] 2
# ['Jonathan', 'Parsons'] 2
# ['Karen', 'Burke'] 2
# ['Maria', 'Mosley'] 2
# ['Samuel', 'Cox'] 2
# ['Xavier', 'Grimes'] 2
# ['Brian', 'Pena'] 2
# ['Michael', 'Hampton'] 2
# ['Kyle', 'Ballard'] 2
# ['Monica', 'Shah'] 2
# ['Phillip', 'Gross'] 2
# ['Lindsey', 'Tyler', 'DVM'] 3
# ['Richard', 'Keller'] 2
# ['Donna', 'Smith'] 2
# ['Derek', 'Myers'] 2
# ['Nicole', 'Robertson'] 2
# ['Albert', 'Nguyen'] 2
# ['Erica', 'Villa']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-f0001781f778> in <module>
#       1 # Split the student name and determine the length of the split name.
#       2 for name in student_names:
# ----> 3     print(name.split(), len(name.split()))
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

# %%
print(students_to_fix)

# %%
# Add the prefixes less than or equal to 4 to a new list.
prefixes = []
for name in students_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

print(prefixes)

# %%
# Add the suffixes less than or equal to 3 to a new list.
suffixes = []
for name in students_to_fix:
    if len(name.split()[-1]) <= 3:
        suffixes.append(name.split()[-1])

print(suffixes)

# %%
# Get the unique items in the "prefixes" list.
set(prefixes)

# %%
#Get the unique items in the "suffixes" list.
set(suffixes)

# %%
# Strip "Mrs." from the student names
for name in students_to_fix:
    print(name.strip("Mrs."))

# %%
# Replace "Dr." with an empty string.
name = "Dr. Linda Santiago"
name.replace("Dr.", "")

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# %%
# Iterate through the "prefixes_suffixes" list and replace them with an empty space, "" when it appears in the student's name.
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
